# %%
# Check GPU memory, clear and recheck
from numba import cuda
gpu = cuda.select_device(0)
print('Selected GPU is:', gpu)
memory = cuda.current_context().get_memory_info()
print('Memory Status:', memory[0], 'free out of', memory[1], ',', (int(memory[0])/int(memory[1])*100), '% free')

# print('Clearing Memory...')
# gpu = cuda.select_device(0)
# gpu.reset()
# memory = cuda.current_context().get_memory_info()
# print('Memory Status:', memory[0], 'free out of', memory[1], ',', (int(memory[0])/int(memory[1])*100), '% free')
# Out:
# Selected GPU is: <CUDA device 0 'b'Quadro M4000''>
# Memory Status: 7200217497 free out of 8589934592 , 83.8215637137182 % free

# %%
"""
Created on Wed Feb 26 17:01:56 2020

"""

""" IMPORTS """
import sys
import numpy as np
np.random.seed(1337)  # for reproducibility
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.datasets import mnist
from tensorflow.keras.constraints import *
from sklearn.model_selection import train_test_split
# from keras.utils import np_utils

from binary_ops import binary_tanh as binary_tanh_op
from binary_layers import BinaryDense, BinaryConv2D

import h5py
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
from lambda_layers import *
# %matplotlib qt

# %%
""" FUNCTIION AND VARIABLE DEFINITIONS """
def binary_tanh(x):
    return binary_tanh_op(x)

H = 1.
kernel_lr_multiplier = 'Glorot'

# # nn
batch_size = 50
epochs = 20
channels = 1
img_rows = 30
img_cols = 30
filters = 32
kernel_size = (32, 32)
pool_size = (2, 2)
hidden_units = 128
classes = 10
use_bias = False

# # learning rate schedule
lr_start = 1e-3
lr_end = 1e-4
lr_decay = (lr_end / lr_start)**(1. / epochs)

# # BN
epsilon = 1e-6
momentum = 0.9

# # dropout
p1 = 0.25
p2 = 0.5

hdf5_dir = Path("../data/hdf5/")

def read_many_hdf5(num_images):
    """ Reads image from HDF5.
        Parameters:
        ---------------
        num_images   number of images to read
        Returns:
        ----------
        images      images array, (N, 32, 32, 3) to be stored
        labels      associated meta data, int label (N, 1)
    """
    images= []

    # Open the HDF5 file
    file = h5py.File(hdf5_dir / f"{num_images}_vids.h5", "r+")

    images = np.array(file["/images"]).astype("float32")

    return images

def np_streak(x):
    input_dims = np.shape(x)
    output_shape = (input_dims[0],input_dims[1],input_dims[1]+input_dims[2],input_dims[3],input_dims[4])
    streak_tensor = np.zeros(output_shape)
    for i in range(output_shape[0]):
        for j in range(output_shape[1]):
            streak_tensor[i,j,j:(output_shape[3]+j),:,:] = x[i,j,:,:,:]
    #return streak_tensor
    return np.sum(streak_tensor,axis=1)

def mask(val,ims,mask):
    for i in range(np.shape(val)[0]):
        for j in range(np.shape(val)[1]):
            val[i,j,:,:] = ims[i,j,:,:] * mask
    return val

ACCURACY_THRESHOLD = 0.035

class myCallback(tf.keras.callbacks.Callback):
	def on_epoch_end(self, epoch, logs={}):
		if(logs.get('val_loss') < ACCURACY_THRESHOLD):
			print("\nReached %2.2f%% accuracy, so stopping training!!" %(ACCURACY_THRESHOLD*100))
			self.model.stop_training = True

# Instantiate a callback object
threshold = myCallback()

def custom_loss(y_true, y_pred):

  ssim_loss = (1.0-tf.image.ssim(y_true,y_pred,1))/2.0
  mse_loss = K.mean(K.square(y_pred-y_true))
  #mse_loss = tf.keras.losses.mean_squared_error(y_true,y_pred)

  ssim_loss = 0.5*ssim_loss
  mse_loss = 0.5*mse_loss

  return ssim_loss + mse_loss

def ssim_loss(y_true,y_pred):  
    return (1.0-tf.image.ssim(y_true,y_pred,1))/2.0


### 3943
# ims = read_many_hdf5(3943)
# # ims = np.ones((3943,30,32,32,1))
# ims = np.reshape(ims, (-1,30,32,32,1))
# ims = ims[:3900]
# # temp = np.zeros((1,32,32,1))
# validate2 = np.zeros((3900,30,32,32,1))
# bk_temp = np.random.randint(0,2,(1,32,32,1))
# validate2 = mask(validate2,ims,bk_temp)
# ims2 = np_streak(validate2)

#### 1515
#ims = read_many_hdf5(1516)
# ims = np.ones((3943,30,32,32,1))
#ims = np.reshape(ims, (-1,30,32,32,1))
#ims = ims[:1500]
# temp = np.zeros((1,32,32,1))
#validate2 = np.zeros((1500,30,32,32,1))
#bk_temp = np.random.randint(0,2,(1,32,32,1))
#validate2 = mask(validate2,ims,bk_temp)
#ims2 = np_streak(validate2)

ims = read_many_hdf5(784)
# ims = np.ones((3943,30,32,32,1))
ims = np.reshape(ims, (-1,30,32,32,1))
ims = ims[:750]
# temp = np.zeros((1,32,32,1))
validate2 = np.zeros((750,30,32,32,1))
bk_temp = np.random.randint(0,2,(1,32,32,1))
validate2 = mask(validate2,ims,bk_temp)
ims2 = np_streak(validate2)


validate = ims

validate = validate / 255
ims2 = ims2 /255
ims = ims/255
#X_train, X_test, y_train, y_test = train_test_split(ims, validate, test_size=(1/3), random_state=42)
X_train, X_test, y_train, y_test = train_test_split(ims2, validate, test_size=(1/3), random_state=42)

MX_train, MX_test, My_train, My_test = train_test_split(ims,ims, test_size = 1/3, random_state = 42)

print(np.shape(X_test))
print(np.shape(X_train))

reduce_lr = ReduceLROnPlateau(monitor='val_loss',verbose=1, factor=0.2,
                              patience=5, min_lr=0.00001)
early_stopping = EarlyStopping(patience=20,verbose=1,restore_best_weights=True)
# Out:
# (250, 62, 32, 1)
# (500, 62, 32, 1)

# %%
fix, ax = plt.subplots(nrows = 1, ncols = 4)
i2t = np.reshape(MX_train,(-1,30,32,32))
for col in range(4):
    ax[col].imshow(i2t[10+(6*col)][10],cmap="gray")

# %%
""" MODEL DEFINITION """
model = Sequential()
model.add(Input(shape=(30,32,32,1),batch_size = 50))
model.add(TimeDistributed(BinaryConv2D(1, kernel_size=(32,32), input_shape=(30,32,32,1),
                       data_format='channels_last',
                       H=H, kernel_lr_multiplier=kernel_lr_multiplier,
                       padding='same', use_bias=use_bias, name='bin_conv_1')))
model.add(Lambda(streak,output_shape=streak_output_shape))
model.add(Lambda(integrate_ims, output_shape = integrate_ims_output_shape))
model.add(Flatten())
model.add(Dense(30720, activation = 'relu'))
model.add(Reshape((30,32,32,1)))
model.compile(optimizer = Nadam(0.0001), loss = custom_loss, metrics = ['mean_squared_error'])
model.summary()
history = model.fit(MX_train, My_train,
          batch_size = 50,epochs= 100,
          verbose=2,validation_data=(MX_test,My_test))
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_9 (TimeDist (50, 30, 32, 32, 1)       1024
# _________________________________________________________________
# lambda_18 (Lambda)           (50, 30, 62, 32, 1)       0
# _________________________________________________________________
# lambda_19 (Lambda)           (50, 62, 32, 1)           0
# _________________________________________________________________
# flatten_9 (Flatten)          (50, 1984)                0
# _________________________________________________________________
# dense_8 (Dense)              (50, 30720)               60979200
# _________________________________________________________________
# reshape_8 (Reshape)          (50, 30, 32, 32, 1)       0
# =================================================================
# Total params: 60,980,224
# Trainable params: 60,980,224
# Non-trainable params: 0
# _________________________________________________________________
# Train on 500 samples, validate on 250 samples
# Epoch 1/100
# 500/500 - 4s - loss: 0.3627 - mean_squared_error: 0.2313 - val_loss: 0.3133 - val_mean_squared_error: 0.1370
# Epoch 2/100
# 500/500 - 2s - loss: 0.3138 - mean_squared_error: 0.1387 - val_loss: 0.3120 - val_mean_squared_error: 0.1356
# Epoch 3/100
# 500/500 - 2s - loss: 0.3108 - mean_squared_error: 0.1350 - val_loss: 0.3091 - val_mean_squared_error: 0.1307
# Epoch 4/100
# 500/500 - 2s - loss: 0.3083 - mean_squared_error: 0.1318 - val_loss: 0.3064 - val_mean_squared_error: 0.1265
# Epoch 5/100
# 500/500 - 2s - loss: 0.3062 - mean_squared_error: 0.1292 - val_loss: 0.3073 - val_mean_squared_error: 0.1284
# Epoch 6/100
# 500/500 - 2s - loss: 0.3048 - mean_squared_error: 0.1276 - val_loss: 0.3085 - val_mean_squared_error: 0.1311
# Epoch 7/100
# 500/500 - 2s - loss: 0.3053 - mean_squared_error: 0.1294 - val_loss: 0.3034 - val_mean_squared_error: 0.1222
# Epoch 8/100
# 500/500 - 2s - loss: 0.3026 - mean_squared_error: 0.1255 - val_loss: 0.3069 - val_mean_squared_error: 0.1289
# Epoch 9/100
# 500/500 - 2s - loss: 0.3025 - mean_squared_error: 0.1259 - val_loss: 0.3081 - val_mean_squared_error: 0.1312
# Epoch 10/100
# 500/500 - 2s - loss: 0.3022 - mean_squared_error: 0.1260 - val_loss: 0.3081 - val_mean_squared_error: 0.1313
# Epoch 11/100
# 500/500 - 2s - loss: 0.3021 - mean_squared_error: 0.1267 - val_loss: 0.3051 - val_mean_squared_error: 0.1263
# Epoch 12/100
# 500/500 - 2s - loss: 0.3012 - mean_squared_error: 0.1254 - val_loss: 0.3048 - val_mean_squared_error: 0.1258
# Epoch 13/100
# 500/500 - 2s - loss: 0.3006 - mean_squared_error: 0.1250 - val_loss: 0.3039 - val_mean_squared_error: 0.1242
# Epoch 14/100
# 500/500 - 2s - loss: 0.2997 - mean_squared_error: 0.1241 - val_loss: 0.3043 - val_mean_squared_error: 0.1250
# Epoch 15/100
# 500/500 - 2s - loss: 0.2994 - mean_squared_error: 0.1239 - val_loss: 0.3044 - val_mean_squared_error: 0.1253
# Epoch 16/100
# 500/500 - 2s - loss: 0.2990 - mean_squared_error: 0.1237 - val_loss: 0.3036 - val_mean_squared_error: 0.1242
# Epoch 17/100
# 500/500 - 2s - loss: 0.2989 - mean_squared_error: 0.1240 - val_loss: 0.3029 - val_mean_squared_error: 0.1230
# Epoch 18/100
# 500/500 - 2s - loss: 0.2980 - mean_squared_error: 0.1229 - val_loss: 0.3043 - val_mean_squared_error: 0.1255
# Epoch 19/100
# 500/500 - 2s - loss: 0.2985 - mean_squared_error: 0.1240 - val_loss: 0.3015 - val_mean_squared_error: 0.1208
# Epoch 20/100
# 500/500 - 2s - loss: 0.2971 - mean_squared_error: 0.1222 - val_loss: 0.3021 - val_mean_squared_error: 0.1220
# Epoch 21/100
# 500/500 - 2s - loss: 0.2968 - mean_squared_error: 0.1221 - val_loss: 0.3023 - val_mean_squared_error: 0.1221
# Epoch 22/100
# 500/500 - 2s - loss: 0.2967 - mean_squared_error: 0.1224 - val_loss: 0.3018 - val_mean_squared_error: 0.1216
# Epoch 23/100
# 500/500 - 2s - loss: 0.2962 - mean_squared_error: 0.1218 - val_loss: 0.3004 - val_mean_squared_error: 0.1192
# Epoch 24/100
# 500/500 - 2s - loss: 0.2958 - mean_squared_error: 0.1214 - val_loss: 0.3012 - val_mean_squared_error: 0.1204
# Epoch 25/100
# 500/500 - 2s - loss: 0.2953 - mean_squared_error: 0.1211 - val_loss: 0.3018 - val_mean_squared_error: 0.1218
# Epoch 26/100
# 500/500 - 2s - loss: 0.2949 - mean_squared_error: 0.1205 - val_loss: 0.3029 - val_mean_squared_error: 0.1235
# Epoch 27/100
# 500/500 - 2s - loss: 0.2954 - mean_squared_error: 0.1217 - val_loss: 0.3006 - val_mean_squared_error: 0.1200
# Epoch 28/100
# 500/500 - 2s - loss: 0.2948 - mean_squared_error: 0.1211 - val_loss: 0.3002 - val_mean_squared_error: 0.1195
# Epoch 29/100
# 500/500 - 2s - loss: 0.2942 - mean_squared_error: 0.1207 - val_loss: 0.3004 - val_mean_squared_error: 0.1196
# Epoch 30/100
# 500/500 - 2s - loss: 0.2936 - mean_squared_error: 0.1197 - val_loss: 0.3020 - val_mean_squared_error: 0.1228
# Epoch 31/100
# 500/500 - 2s - loss: 0.2936 - mean_squared_error: 0.1202 - val_loss: 0.3012 - val_mean_squared_error: 0.1213
# Epoch 32/100
# 500/500 - 2s - loss: 0.2931 - mean_squared_error: 0.1196 - val_loss: 0.3012 - val_mean_squared_error: 0.1214
# Epoch 33/100
# 500/500 - 2s - loss: 0.2928 - mean_squared_error: 0.1195 - val_loss: 0.3011 - val_mean_squared_error: 0.1212
# Epoch 34/100
# 500/500 - 2s - loss: 0.2931 - mean_squared_error: 0.1202 - val_loss: 0.2996 - val_mean_squared_error: 0.1187
# Epoch 35/100
# 500/500 - 2s - loss: 0.2920 - mean_squared_error: 0.1187 - val_loss: 0.3028 - val_mean_squared_error: 0.1243
# Epoch 36/100
# 500/500 - 2s - loss: 0.2922 - mean_squared_error: 0.1194 - val_loss: 0.3013 - val_mean_squared_error: 0.1219
# Epoch 37/100
# 500/500 - 2s - loss: 0.2922 - mean_squared_error: 0.1196 - val_loss: 0.3004 - val_mean_squared_error: 0.1200
# Epoch 38/100
# 500/500 - 2s - loss: 0.2912 - mean_squared_error: 0.1181 - val_loss: 0.3038 - val_mean_squared_error: 0.1264
# Epoch 39/100
# 500/500 - 2s - loss: 0.2920 - mean_squared_error: 0.1200 - val_loss: 0.3001 - val_mean_squared_error: 0.1198
# Epoch 40/100
# 500/500 - 2s - loss: 0.2907 - mean_squared_error: 0.1180 - val_loss: 0.3003 - val_mean_squared_error: 0.1205
# Epoch 41/100
# 500/500 - 2s - loss: 0.2902 - mean_squared_error: 0.1176 - val_loss: 0.3008 - val_mean_squared_error: 0.1208
# Epoch 42/100
# 500/500 - 2s - loss: 0.2904 - mean_squared_error: 0.1178 - val_loss: 0.3012 - val_mean_squared_error: 0.1218
# Epoch 43/100
# 500/500 - 2s - loss: 0.2903 - mean_squared_error: 0.1181 - val_loss: 0.2985 - val_mean_squared_error: 0.1172
# Epoch 44/100
# 500/500 - 2s - loss: 0.2901 - mean_squared_error: 0.1180 - val_loss: 0.2980 - val_mean_squared_error: 0.1161
# Epoch 45/100
# 500/500 - 2s - loss: 0.2893 - mean_squared_error: 0.1169 - val_loss: 0.3006 - val_mean_squared_error: 0.1209
# Epoch 46/100
# 500/500 - 2s - loss: 0.2892 - mean_squared_error: 0.1171 - val_loss: 0.2997 - val_mean_squared_error: 0.1194
# Epoch 47/100
# 500/500 - 2s - loss: 0.2891 - mean_squared_error: 0.1174 - val_loss: 0.2993 - val_mean_squared_error: 0.1189
# Epoch 48/100
# 500/500 - 2s - loss: 0.2888 - mean_squared_error: 0.1169 - val_loss: 0.2992 - val_mean_squared_error: 0.1187
# Epoch 49/100
# 500/500 - 2s - loss: 0.2884 - mean_squared_error: 0.1166 - val_loss: 0.2989 - val_mean_squared_error: 0.1179
# Epoch 50/100
# 500/500 - 2s - loss: 0.2882 - mean_squared_error: 0.1164 - val_loss: 0.2982 - val_mean_squared_error: 0.1168
# Epoch 51/100
# 500/500 - 2s - loss: 0.2881 - mean_squared_error: 0.1165 - val_loss: 0.2976 - val_mean_squared_error: 0.1157
# Epoch 52/100
# 500/500 - 2s - loss: 0.2872 - mean_squared_error: 0.1153 - val_loss: 0.2991 - val_mean_squared_error: 0.1186
# Epoch 53/100
# 500/500 - 2s - loss: 0.2871 - mean_squared_error: 0.1151 - val_loss: 0.3016 - val_mean_squared_error: 0.1228
# Epoch 54/100
# 500/500 - 2s - loss: 0.2887 - mean_squared_error: 0.1182 - val_loss: 0.2976 - val_mean_squared_error: 0.1158
# Epoch 55/100
# 500/500 - 2s - loss: 0.2866 - mean_squared_error: 0.1150 - val_loss: 0.2993 - val_mean_squared_error: 0.1191
# Epoch 56/100
# 500/500 - 2s - loss: 0.2867 - mean_squared_error: 0.1154 - val_loss: 0.3012 - val_mean_squared_error: 0.1224
# Epoch 57/100
# 500/500 - 2s - loss: 0.2871 - mean_squared_error: 0.1161 - val_loss: 0.3003 - val_mean_squared_error: 0.1208
# Epoch 58/100
# 500/500 - 2s - loss: 0.2862 - mean_squared_error: 0.1150 - val_loss: 0.3011 - val_mean_squared_error: 0.1222
# Epoch 59/100
# 500/500 - 2s - loss: 0.2864 - mean_squared_error: 0.1155 - val_loss: 0.2983 - val_mean_squared_error: 0.1175
# Epoch 60/100
# 500/500 - 2s - loss: 0.2861 - mean_squared_error: 0.1152 - val_loss: 0.2992 - val_mean_squared_error: 0.1192
# Epoch 61/100
# 500/500 - 2s - loss: 0.2858 - mean_squared_error: 0.1151 - val_loss: 0.2988 - val_mean_squared_error: 0.1184
# Epoch 62/100
# 500/500 - 2s - loss: 0.2858 - mean_squared_error: 0.1151 - val_loss: 0.2980 - val_mean_squared_error: 0.1169
# Epoch 63/100
# 500/500 - 2s - loss: 0.2848 - mean_squared_error: 0.1137 - val_loss: 0.2986 - val_mean_squared_error: 0.1181
# Epoch 64/100
# 500/500 - 2s - loss: 0.2850 - mean_squared_error: 0.1144 - val_loss: 0.2980 - val_mean_squared_error: 0.1169
# Epoch 65/100
# 500/500 - 2s - loss: 0.2850 - mean_squared_error: 0.1145 - val_loss: 0.2971 - val_mean_squared_error: 0.1157
# Epoch 66/100
# 500/500 - 2s - loss: 0.2843 - mean_squared_error: 0.1136 - val_loss: 0.2998 - val_mean_squared_error: 0.1203
# Epoch 67/100
# 500/500 - 2s - loss: 0.2844 - mean_squared_error: 0.1139 - val_loss: 0.2997 - val_mean_squared_error: 0.1199
# Epoch 68/100
# 500/500 - 2s - loss: 0.2845 - mean_squared_error: 0.1142 - val_loss: 0.2978 - val_mean_squared_error: 0.1168
# Epoch 69/100
# 500/500 - 2s - loss: 0.2839 - mean_squared_error: 0.1134 - val_loss: 0.2975 - val_mean_squared_error: 0.1165
# Epoch 70/100
# 500/500 - 2s - loss: 0.2829 - mean_squared_error: 0.1123 - val_loss: 0.3002 - val_mean_squared_error: 0.1208
# Epoch 71/100
# 500/500 - 2s - loss: 0.2840 - mean_squared_error: 0.1140 - val_loss: 0.2972 - val_mean_squared_error: 0.1160
# Epoch 72/100
# 500/500 - 2s - loss: 0.2831 - mean_squared_error: 0.1126 - val_loss: 0.2994 - val_mean_squared_error: 0.1199
# Epoch 73/100
# 500/500 - 2s - loss: 0.2834 - mean_squared_error: 0.1135 - val_loss: 0.2990 - val_mean_squared_error: 0.1189
# Epoch 74/100
# 500/500 - 2s - loss: 0.2834 - mean_squared_error: 0.1135 - val_loss: 0.2981 - val_mean_squared_error: 0.1175
# Epoch 75/100
# 500/500 - 2s - loss: 0.2826 - mean_squared_error: 0.1125 - val_loss: 0.2979 - val_mean_squared_error: 0.1171
# Epoch 76/100
# 500/500 - 2s - loss: 0.2826 - mean_squared_error: 0.1125 - val_loss: 0.2981 - val_mean_squared_error: 0.1174
# Epoch 77/100
# 500/500 - 2s - loss: 0.2824 - mean_squared_error: 0.1125 - val_loss: 0.2972 - val_mean_squared_error: 0.1161
# Epoch 78/100
# 500/500 - 2s - loss: 0.2823 - mean_squared_error: 0.1126 - val_loss: 0.2971 - val_mean_squared_error: 0.1157
# Epoch 79/100
# 500/500 - 2s - loss: 0.2828 - mean_squared_error: 0.1135 - val_loss: 0.2969 - val_mean_squared_error: 0.1157
# Epoch 80/100
# 500/500 - 2s - loss: 0.2822 - mean_squared_error: 0.1128 - val_loss: 0.2972 - val_mean_squared_error: 0.1157
# Epoch 81/100
# 500/500 - 2s - loss: 0.2817 - mean_squared_error: 0.1120 - val_loss: 0.2966 - val_mean_squared_error: 0.1149
# Epoch 82/100
# 500/500 - 2s - loss: 0.2812 - mean_squared_error: 0.1113 - val_loss: 0.2984 - val_mean_squared_error: 0.1186
# Epoch 83/100
# 500/500 - 2s - loss: 0.2816 - mean_squared_error: 0.1124 - val_loss: 0.2979 - val_mean_squared_error: 0.1172
# Epoch 84/100
# 500/500 - 2s - loss: 0.2814 - mean_squared_error: 0.1118 - val_loss: 0.2988 - val_mean_squared_error: 0.1188
# Epoch 85/100
# 500/500 - 2s - loss: 0.2821 - mean_squared_error: 0.1134 - val_loss: 0.2981 - val_mean_squared_error: 0.1178
# Epoch 86/100
# 500/500 - 2s - loss: 0.2819 - mean_squared_error: 0.1130 - val_loss: 0.2982 - val_mean_squared_error: 0.1184
# Epoch 87/100
# 500/500 - 2s - loss: 0.2818 - mean_squared_error: 0.1133 - val_loss: 0.2963 - val_mean_squared_error: 0.1146
# Epoch 88/100
# 500/500 - 2s - loss: 0.2812 - mean_squared_error: 0.1123 - val_loss: 0.2967 - val_mean_squared_error: 0.1152
# Epoch 89/100
# 500/500 - 2s - loss: 0.2803 - mean_squared_error: 0.1110 - val_loss: 0.2969 - val_mean_squared_error: 0.1161
# Epoch 90/100
# 500/500 - 2s - loss: 0.2807 - mean_squared_error: 0.1120 - val_loss: 0.2975 - val_mean_squared_error: 0.1168
# Epoch 91/100
# 500/500 - 2s - loss: 0.2802 - mean_squared_error: 0.1113 - val_loss: 0.2977 - val_mean_squared_error: 0.1172
# Epoch 92/100
# 500/500 - 2s - loss: 0.2805 - mean_squared_error: 0.1120 - val_loss: 0.2959 - val_mean_squared_error: 0.1142
# Epoch 93/100
# 500/500 - 2s - loss: 0.2796 - mean_squared_error: 0.1107 - val_loss: 0.2967 - val_mean_squared_error: 0.1152
# Epoch 94/100
# 500/500 - 2s - loss: 0.2799 - mean_squared_error: 0.1112 - val_loss: 0.2958 - val_mean_squared_error: 0.1141
# Epoch 95/100
# 500/500 - 2s - loss: 0.2801 - mean_squared_error: 0.1118 - val_loss: 0.2963 - val_mean_squared_error: 0.1149
# Epoch 96/100
# 500/500 - 2s - loss: 0.2791 - mean_squared_error: 0.1104 - val_loss: 0.2963 - val_mean_squared_error: 0.1150
# Epoch 97/100
# 500/500 - 2s - loss: 0.2789 - mean_squared_error: 0.1101 - val_loss: 0.2972 - val_mean_squared_error: 0.1168
# Epoch 98/100
# 500/500 - 2s - loss: 0.2796 - mean_squared_error: 0.1115 - val_loss: 0.2955 - val_mean_squared_error: 0.1133
# Epoch 99/100
# 500/500 - 2s - loss: 0.2781 - mean_squared_error: 0.1092 - val_loss: 0.2960 - val_mean_squared_error: 0.1146
# Epoch 100/100
# 500/500 - 2s - loss: 0.2783 - mean_squared_error: 0.1099 - val_loss: 0.2964 - val_mean_squared_error: 0.1148

# %%
m1_y_pred = model.predict(MX_test)
show_video(m1_y_pred,MX_test,15)

# %%
from binary_ops import *
get_mask(model)

# %%
def get_mask(model,l=0):
    b = binarize(model.layers[l].weights[0])
    figb,axb = plt.subplots(1,1)
    axb.imshow(np.reshape(b,(32,32)),cmap="gray")

# %%
""" FULL MODEL """
from binary_ops import binary_tanh as binary_tanh_op
from binary_layers import BinaryDense, BinaryConv2D

inputs = Input(shape=(30,32,32,1),batch_size=50)
bin_conv1 = TimeDistributed(BinaryConv2D(1, kernel_size=(32,32), input_shape=(30,32,32,1),
                       data_format='channels_last',
                       H=H, kernel_lr_multiplier=kernel_lr_multiplier,
                       padding='same', use_bias=use_bias, name='bin_conv_1'))(inputs)
s = Lambda(streak, output_shape = streak_output_shape)(bin_conv1)
i = Lambda(integrate_ims, output_shape = integrate_ims_output_shape) (s)
f = Flatten()(i)
dense1 = Dense(30720, activation = 'relu')(f)
resh = Reshape((30,32,32,1))(dense1)
c1 = TimeDistributed(Conv2D(1, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (resh)
c1 = Dropout(0.1) (c1)
c1 = TimeDistributed(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c1)
p1 = TimeDistributed(MaxPooling2D((2, 2)))(c1)

c2 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))(p1)
c2 = Dropout(0.1) (c2)
c2 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c2)
p2 = TimeDistributed(MaxPooling2D((2, 2)) )(c2)

c3 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(p2)
c3 = Dropout(0.2) (c3)
c3 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c3)
p3 = TimeDistributed(MaxPooling2D((2, 2)) )(c3)
    
c4 = TimeDistributed(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(p3)
c4 = Dropout(0.2) (c4)
c4 = TimeDistributed(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c4)
p4 = TimeDistributed(MaxPooling2D(pool_size=(2, 2))) (c4)

c5 = TimeDistributed(Conv2D(256, (2, 2), activation='relu', kernel_initializer='he_normal', padding='same')) (p4)
c5 = Dropout(0.3) (c5)
c5 = TimeDistributed(Conv2D(256, (2, 2), activation='relu', kernel_initializer='he_normal', padding='same')) (c5)

u6 = TimeDistributed(Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same'))(c5)
u6 = concatenate([u6, c4])
c6 = TimeDistributed( Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(u6)
c6 = Dropout(0.2) (c6)
c6 = TimeDistributed(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c6)

u7 = TimeDistributed(Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same') )(c6)
u7 = concatenate([u7, c3])
c7 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (u7)
c7 = Dropout(0.2) (c7)
c7 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c7)
    
u8 = TimeDistributed(Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same') )(c7)
u8 = concatenate([u8, c2])
c8 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (u8)
c8 = Dropout(0.1) (c8)
c8 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c8)

u9 = TimeDistributed(Conv2DTranspose(16, (3, 3), strides=(2, 2), padding='same')) (c8)
c9 = TimeDistributed(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (u9)
c9 = Dropout(0.1) (c9)
c9 = TimeDistributed(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c9)
    
outputs = TimeDistributed(Conv2D(1, (1, 1), activation='sigmoid')) (c9)

CUPNET = Model(inputs = [inputs], outputs = [outputs])
    
CUPNET.compile(optimizer = Nadam(0.0001), loss = custom_loss, metrics = ['mean_squared_error'])

# %%
CUPNET.summary()
cupnet_history = CUPNET.fit(MX_train, My_train,
          batch_size = 50,epochs= 500,
          verbose=2,validation_data=(MX_test,My_test))
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(50, 30, 32, 32, 1) 0
# __________________________________________________________________________________________________
# time_distributed_72 (TimeDistri (50, 30, 32, 32, 1)  1024        input_4[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (50, 30, 62, 32, 1)  0           time_distributed_72[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (50, 62, 32, 1)      0           lambda_6[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (50, 1984)           0           lambda_7[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (50, 30720)          60979200    flatten_3[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (50, 30, 32, 32, 1)  0           dense_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_73 (TimeDistri (50, 30, 32, 32, 16) 80          reshape_3[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (50, 30, 32, 32, 16) 0           time_distributed_73[0][0]
# __________________________________________________________________________________________________
# time_distributed_74 (TimeDistri (50, 30, 32, 32, 16) 1040        dropout_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_75 (TimeDistri (50, 30, 16, 16, 16) 0           time_distributed_74[0][0]
# __________________________________________________________________________________________________
# time_distributed_76 (TimeDistri (50, 30, 16, 16, 32) 2080        time_distributed_75[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (50, 30, 16, 16, 32) 0           time_distributed_76[0][0]
# __________________________________________________________________________________________________
# time_distributed_77 (TimeDistri (50, 30, 16, 16, 32) 4128        dropout_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_78 (TimeDistri (50, 30, 8, 8, 32)   0           time_distributed_77[0][0]
# __________________________________________________________________________________________________
# time_distributed_79 (TimeDistri (50, 30, 8, 8, 64)   8256        time_distributed_78[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (50, 30, 8, 8, 64)   0           time_distributed_79[0][0]
# __________________________________________________________________________________________________
# time_distributed_80 (TimeDistri (50, 30, 8, 8, 64)   16448       dropout_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_81 (TimeDistri (50, 30, 4, 4, 64)   0           time_distributed_80[0][0]
# __________________________________________________________________________________________________
# time_distributed_82 (TimeDistri (50, 30, 4, 4, 128)  32896       time_distributed_81[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (50, 30, 4, 4, 128)  0           time_distributed_82[0][0]
# __________________________________________________________________________________________________
# time_distributed_83 (TimeDistri (50, 30, 4, 4, 128)  65664       dropout_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_84 (TimeDistri (50, 30, 2, 2, 128)  0           time_distributed_83[0][0]
# __________________________________________________________________________________________________
# time_distributed_85 (TimeDistri (50, 30, 2, 2, 256)  131328      time_distributed_84[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (50, 30, 2, 2, 256)  0           time_distributed_85[0][0]
# __________________________________________________________________________________________________
# time_distributed_86 (TimeDistri (50, 30, 2, 2, 256)  262400      dropout_27[0][0]
# __________________________________________________________________________________________________
# time_distributed_87 (TimeDistri (50, 30, 4, 4, 128)  131200      time_distributed_86[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (50, 30, 4, 4, 256)  0           time_distributed_87[0][0]
#                                                                  time_distributed_83[0][0]
# __________________________________________________________________________________________________
# time_distributed_88 (TimeDistri (50, 30, 4, 4, 128)  131200      concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (50, 30, 4, 4, 128)  0           time_distributed_88[0][0]
# __________________________________________________________________________________________________
# time_distributed_89 (TimeDistri (50, 30, 4, 4, 128)  65664       dropout_28[0][0]
# __________________________________________________________________________________________________
# time_distributed_90 (TimeDistri (50, 30, 8, 8, 64)   32832       time_distributed_89[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (50, 30, 8, 8, 128)  0           time_distributed_90[0][0]
#                                                                  time_distributed_80[0][0]
# __________________________________________________________________________________________________
# time_distributed_91 (TimeDistri (50, 30, 8, 8, 64)   32832       concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (50, 30, 8, 8, 64)   0           time_distributed_91[0][0]
# __________________________________________________________________________________________________
# time_distributed_92 (TimeDistri (50, 30, 8, 8, 64)   36928       dropout_29[0][0]
# __________________________________________________________________________________________________
# time_distributed_93 (TimeDistri (50, 30, 16, 16, 32) 8224        time_distributed_92[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (50, 30, 16, 16, 64) 0           time_distributed_93[0][0]
#                                                                  time_distributed_77[0][0]
# __________________________________________________________________________________________________
# time_distributed_94 (TimeDistri (50, 30, 16, 16, 32) 8224        concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (50, 30, 16, 16, 32) 0           time_distributed_94[0][0]
# __________________________________________________________________________________________________
# time_distributed_95 (TimeDistri (50, 30, 16, 16, 32) 4128        dropout_30[0][0]
# __________________________________________________________________________________________________
# time_distributed_96 (TimeDistri (50, 30, 32, 32, 16) 2064        time_distributed_95[0][0]
# __________________________________________________________________________________________________
# time_distributed_97 (TimeDistri (50, 30, 32, 32, 16) 1040        time_distributed_96[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (50, 30, 32, 32, 16) 0           time_distributed_97[0][0]
# __________________________________________________________________________________________________
# time_distributed_98 (TimeDistri (50, 30, 32, 32, 16) 1040        dropout_31[0][0]
# __________________________________________________________________________________________________
# time_distributed_99 (TimeDistri (50, 30, 32, 32, 1)  17          time_distributed_98[0][0]
# ==================================================================================================
# Total params: 61,959,937
# Trainable params: 61,959,937
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 397/500
# 500/500 - 8s - loss: 0.2081 - mean_squared_error: 0.0396 - val_loss: 0.2154 - val_mean_squared_error: 0.0434
# Epoch 398/500
# 500/500 - 8s - loss: 0.2080 - mean_squared_error: 0.0395 - val_loss: 0.2157 - val_mean_squared_error: 0.0438
# Epoch 399/500
# 500/500 - 8s - loss: 0.2080 - mean_squared_error: 0.0396 - val_loss: 0.2158 - val_mean_squared_error: 0.0435
# Epoch 400/500
# 500/500 - 7s - loss: 0.2078 - mean_squared_error: 0.0393 - val_loss: 0.2158 - val_mean_squared_error: 0.0437
# Epoch 401/500
# 500/500 - 8s - loss: 0.2085 - mean_squared_error: 0.0397 - val_loss: 0.2167 - val_mean_squared_error: 0.0441
# Epoch 402/500
# 500/500 - 7s - loss: 0.2084 - mean_squared_error: 0.0397 - val_loss: 0.2156 - val_mean_squared_error: 0.0435
# Epoch 403/500
# 500/500 - 8s - loss: 0.2080 - mean_squared_error: 0.0393 - val_loss: 0.2155 - val_mean_squared_error: 0.0435
# Epoch 404/500
# 500/500 - 7s - loss: 0.2079 - mean_squared_error: 0.0393 - val_loss: 0.2155 - val_mean_squared_error: 0.0434
# Epoch 405/500
# 500/500 - 7s - loss: 0.2080 - mean_squared_error: 0.0394 - val_loss: 0.2154 - val_mean_squared_error: 0.0433
# Epoch 406/500
# 500/500 - 7s - loss: 0.2079 - mean_squared_error: 0.0394 - val_loss: 0.2153 - val_mean_squared_error: 0.0432
# Epoch 407/500
# 500/500 - 7s - loss: 0.2077 - mean_squared_error: 0.0392 - val_loss: 0.2153 - val_mean_squared_error: 0.0434
# Epoch 408/500
# 500/500 - 8s - loss: 0.2077 - mean_squared_error: 0.0393 - val_loss: 0.2156 - val_mean_squared_error: 0.0434
# Epoch 409/500
# 500/500 - 8s - loss: 0.2081 - mean_squared_error: 0.0395 - val_loss: 0.2157 - val_mean_squared_error: 0.0434
# Epoch 410/500
# 500/500 - 7s - loss: 0.2082 - mean_squared_error: 0.0397 - val_loss: 0.2159 - val_mean_squared_error: 0.0436
# Epoch 411/500
# 500/500 - 7s - loss: 0.2081 - mean_squared_error: 0.0396 - val_loss: 0.2160 - val_mean_squared_error: 0.0437
# Epoch 412/500
# 500/500 - 8s - loss: 0.2081 - mean_squared_error: 0.0395 - val_loss: 0.2155 - val_mean_squared_error: 0.0434
# Epoch 413/500
# 500/500 - 7s - loss: 0.2082 - mean_squared_error: 0.0397 - val_loss: 0.2159 - val_mean_squared_error: 0.0436
# Epoch 414/500
# 500/500 - 7s - loss: 0.2081 - mean_squared_error: 0.0396 - val_loss: 0.2155 - val_mean_squared_error: 0.0432
# Epoch 415/500
# 500/500 - 7s - loss: 0.2081 - mean_squared_error: 0.0396 - val_loss: 0.2157 - val_mean_squared_error: 0.0435
# Epoch 416/500
# 500/500 - 7s - loss: 0.2081 - mean_squared_error: 0.0395 - val_loss: 0.2159 - val_mean_squared_error: 0.0438
# Epoch 417/500
# 500/500 - 7s - loss: 0.2084 - mean_squared_error: 0.0398 - val_loss: 0.2158 - val_mean_squared_error: 0.0435
# Epoch 481/500
# 500/500 - 8s - loss: 0.2066 - mean_squared_error: 0.0376 - val_loss: 0.2144 - val_mean_squared_error: 0.0415
# Epoch 482/500
# 500/500 - 7s - loss: 0.2068 - mean_squared_error: 0.0376 - val_loss: 0.2138 - val_mean_squared_error: 0.0412
# Epoch 483/500
# 500/500 - 8s - loss: 0.2063 - mean_squared_error: 0.0374 - val_loss: 0.2147 - val_mean_squared_error: 0.0421
# Epoch 484/500
# 500/500 - 8s - loss: 0.2065 - mean_squared_error: 0.0375 - val_loss: 0.2135 - val_mean_squared_error: 0.0412
# Epoch 485/500
# 500/500 - 8s - loss: 0.2066 - mean_squared_error: 0.0376 - val_loss: 0.2144 - val_mean_squared_error: 0.0418
# Epoch 486/500
# 500/500 - 8s - loss: 0.2069 - mean_squared_error: 0.0378 - val_loss: 0.2144 - val_mean_squared_error: 0.0415
# Epoch 487/500
# 500/500 - 7s - loss: 0.2064 - mean_squared_error: 0.0374 - val_loss: 0.2138 - val_mean_squared_error: 0.0413
# Epoch 488/500
# 500/500 - 8s - loss: 0.2062 - mean_squared_error: 0.0374 - val_loss: 0.2136 - val_mean_squared_error: 0.0411
# Epoch 489/500
# 500/500 - 7s - loss: 0.2068 - mean_squared_error: 0.0377 - val_loss: 0.2154 - val_mean_squared_error: 0.0423
# Epoch 490/500
# 500/500 - 7s - loss: 0.2074 - mean_squared_error: 0.0382 - val_loss: 0.2150 - val_mean_squared_error: 0.0422
# Epoch 491/500
# 500/500 - 8s - loss: 0.2065 - mean_squared_error: 0.0376 - val_loss: 0.2142 - val_mean_squared_error: 0.0415
# Epoch 492/500
# 500/500 - 7s - loss: 0.2066 - mean_squared_error: 0.0376 - val_loss: 0.2140 - val_mean_squared_error: 0.0411
# Epoch 493/500
# 500/500 - 8s - loss: 0.2063 - mean_squared_error: 0.0373 - val_loss: 0.2140 - val_mean_squared_error: 0.0414
# Epoch 494/500
# 500/500 - 8s - loss: 0.2072 - mean_squared_error: 0.0381 - val_loss: 0.2142 - val_mean_squared_error: 0.0413
# Epoch 495/500
# 500/500 - 8s - loss: 0.2064 - mean_squared_error: 0.0374 - val_loss: 0.2135 - val_mean_squared_error: 0.0410
# Epoch 496/500
# 500/500 - 7s - loss: 0.2062 - mean_squared_error: 0.0372 - val_loss: 0.2138 - val_mean_squared_error: 0.0413
# Epoch 497/500
# 500/500 - 8s - loss: 0.2065 - mean_squared_error: 0.0375 - val_loss: 0.2145 - val_mean_squared_error: 0.0417
# Epoch 498/500
# 500/500 - 7s - loss: 0.2065 - mean_squared_error: 0.0374 - val_loss: 0.2141 - val_mean_squared_error: 0.0413
# Epoch 499/500
# 500/500 - 8s - loss: 0.2064 - mean_squared_error: 0.0373 - val_loss: 0.2139 - val_mean_squared_error: 0.0412
# Epoch 500/500
# 500/500 - 8s - loss: 0.2063 - mean_squared_error: 0.0373 - val_loss: 0.2141 - val_mean_squared_error: 0.0413

# %%
def show_video(y_pred,y_true,num):
    yp = np.reshape(y_pred,(-1,30,32,32))
    yt = np.reshape(y_true,(-1,30,32,32))
    fig,ax = plt.subplots(nrows=5,ncols=6,sharex=True,sharey=True)
    fig2,ax2 = plt.subplots(nrows=5,ncols=6,sharex=True,sharey=True)
    for row in range(5):
        for col in range(6):
            ax[row,col].imshow(yp[num][5*row+col],cmap="gray")
            ax2[row,col].imshow(yt[num][5*row+col],cmap="gray")

# %%
y_pred = CUPNET.predict(MX_test)
y_pred = np.reshape(y_pred,(-1,30,32,32))
fix,ax = plt.subplots(nrows=1,ncols=2)
ax[0].imshow(y_pred[110][10],cmap="gray")
ax[1].imshow(np.reshape(MX_test[110][10],(32,32)),cmap="gray")

# %%
from binary_ops import *
get_mask(CUPNET,1)
show_video(y_pred,MX_test,15)

# %%
show_video(y_pred,MX_test,111)

# %%
def show_all_videos(videos,rows,cols):
    yp = np.reshape(videos, (-1,30,32,32))
    fix3,ax3 = plt.subplots(nrows=rows, ncols = cols)
    for row in range(rows):
        for col in range(cols):
            ax3[row,col].imshow(yp[rows*row+col][3],cmap="gray")

# %%
show_all_videos(y_pred,10,25)

# %%
ims = np.reshape(ims, (-1,30,32,32,1))
ims = ims/255
y_pred = model2.predict(ims2[0:100])
print(np.shape(y_pred))
y_pred = np.reshape(y_pred,(-1,30,32,32))
plt.imshow(y_pred[10][10],cmap="gray")
y_pred[10][10].mean()

# %%
fig, ax = plt.subplots(nrows=5, ncols=6, sharex=True, sharey=True,)
count = 0
for idx in range(5):    
  for jdx in range(6): 
    ax[idx,jdx].imshow(y_pred[10][count],cmap="gray")
    count+=1

# %%
ims = np.reshape(ims,(-1,30,32,32))
fig, ax = plt.subplots(nrows=5, ncols=6, sharex=True, sharey=True,)
count = 0
for idx in range(5):    
  for jdx in range(6): 
    ax[idx,jdx].imshow(ims[10][idx+jdx],cmap="gray")

# %%
tmap = ims[10][0] == ims[10][1]
tmap2 = y_pred[10][0] == y_pred[10][29]
fix2,ax2 = plt.subplots(nrows=4,ncols=3,sharex=True,sharey=True)
ax2[0,0].imshow(ims[10][0],cmap="gray")
ax2[0,1].imshow(ims[10][29],cmap="gray")
ax2[0,2].imshow(tmap,cmap="gray")
ax2[1,0].imshow(y_pred[10][0],cmap="gray")
ax2[1,1].imshow(y_pred[10][29],cmap="gray")
ax2[1,2].imshow(tmap2,cmap="gray")
ax2[2,0].imshow(ims[88][0],cmap="gray")
ax2[2,1].imshow(ims[88][29],cmap="gray")
ax2[2,2].imshow(tmap,cmap="gray")
ax2[3,0].imshow(y_pred[88][0],cmap="gray")
ax2[3,1].imshow(y_pred[88][29],cmap="gray")
ax2[3,2].imshow(tmap2,cmap="gray")

# %%
fig3, ax3 = plt.subplots(nrows= 4, ncols=4,sharex=True,sharey=True)
for idx in range(4):
    for jdx in range(4):
        ax3[idx,jdx].imshow(y_pred[10+idx+jdx][10],cmap="gray")

# %%
fig4, ax4 = plt.subplots(nrows=4, ncols=4, sharex=True,sharey=True)
for idx in range(4):
    for jdx in range(4):
        ax4[idx,jdx].imshow(ims[10+idx+jdx][10],cmap="gray")
