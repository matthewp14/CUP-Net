# %%
"""
Created on Wed Feb 26 17:01:56 2020

"""

""" IMPORTS """
import sys
import numpy as np
np.random.seed(1337)  # for reproducibility
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.datasets import mnist
from tensorflow.keras.constraints import *
from sklearn.model_selection import train_test_split
# from keras.utils import np_utils

from binary_ops import binary_tanh as binary_tanh_op
from binary_layers import BinaryDense, BinaryConv2D

import h5py
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
from lambda_layers import *
from binary_ops import *
# %matplotlib qt

# %%
""" FUNCTIION AND VARIABLE DEFINITIONS """
def binary_tanh(x):
    return binary_tanh_op(x)

H = 1.
kernel_lr_multiplier = 'Glorot'

# # nn
batch_size = 50
epochs = 20
channels = 1
img_rows = 30
img_cols = 30
filters = 32
kernel_size = (32, 32)
pool_size = (2, 2)
hidden_units = 128
classes = 10
use_bias = False

# # learning rate schedule
lr_start = 1e-3
lr_end = 1e-4
lr_decay = (lr_end / lr_start)**(1. / epochs)

# # BN
epsilon = 1e-6
momentum = 0.9

# # dropout
p1 = 0.25
p2 = 0.5

hdf5_dir = Path("../data/hdf5/")

def read_many_hdf5(num_images):
    """ Reads image from HDF5.
        Parameters:
        ---------------
        num_images   number of images to read
        Returns:
        ----------
        images      images array, (N, 32, 32, 3) to be stored
        labels      associated meta data, int label (N, 1)
    """
    images= []

    # Open the HDF5 file
    file = h5py.File(hdf5_dir / f"{num_images}_vids.h5", "r+")

    images = np.array(file["/images"]).astype("float32")

    return images

def np_streak(x):
    input_dims = np.shape(x)
    output_shape = (input_dims[0],input_dims[1],input_dims[1]+input_dims[2],input_dims[3],input_dims[4])
    streak_tensor = np.zeros(output_shape)
    for i in range(output_shape[0]):
        for j in range(output_shape[1]):
            streak_tensor[i,j,j:(output_shape[3]+j),:,:] = x[i,j,:,:,:]
    #return streak_tensor
    return np.sum(streak_tensor,axis=1)

def mask(val,ims,mask):
    for i in range(np.shape(val)[0]):
        for j in range(np.shape(val)[1]):
            val[i,j,:,:] = ims[i,j,:,:] * mask
    return val



yt_vids = read_many_hdf5("youtube")
russian_vids = read_many_hdf5("russian_movie")
jelly_vids = read_many_hdf5("jelly")

ims = np.concatenate((yt_vids,russian_vids,jelly_vids))
ims = ims[:1500]
ims = np.reshape(ims,(-1,30,32,32,1))

validate = ims

validate = validate / 255
#ims2 = ims2 /255
ims = ims/255
#X_train, X_test, y_train, y_test = train_test_split(ims, validate, test_size=(1/3), random_state=42)
#X_train, X_test, y_train, y_test = train_test_split(ims2, validate, test_size=(1/3), random_state=42)

MX_train, MX_test, My_train, My_test = train_test_split(ims,ims, test_size = 0.3, random_state = 42)

print(np.shape(MX_test))
print(np.shape(MX_train))


reduce_lr = ReduceLROnPlateau(monitor='val_loss',verbose=1, factor=0.5,
                              patience=50, min_lr=0.000001)
early_stopping = EarlyStopping(patience=90,verbose=1,restore_best_weights=True)   


def custom_loss(y_true, y_pred):

  ssim_loss = (1.0-tf.image.ssim(y_true,y_pred,1))/2.0
  mse_loss = K.mean(K.square(y_pred-y_true))
  #mse_loss = tf.keras.losses.mean_squared_error(y_true,y_pred)

  ssim_loss = 0.5*ssim_loss
  mse_loss = 0.5*mse_loss

  return ssim_loss + mse_loss

def ssim_loss(y_true,y_pred):  
    return (1.0-tf.image.ssim(y_true,y_pred,1))/2.0

def mse_loss(y_true,y_pred):
    return K.mean(K.square(y_pred-y_true))
# Out:
# (450, 30, 32, 32, 1)
# (1050, 30, 32, 32, 1)

# %%
show_video2(y_pred,My_test,30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-9a2b30647f84> in <module>
# ----> 1 show_video2(y_pred,My_test,30)
#
# <ipython-input-19-3821bd4a2f71> in show_video2(y_pred, y_true, num)
#      32     fig,ax = plt.subplots(nrows=5,ncols=13,sharex=True,sharey=True)
#      33     fig.suptitle(f'Movie: {num} MSE: {mse} SSIM: {ssim}')
# ---> 34     ax[:,6].axis=('off')
#      35     for row in range(5):
#      36         for col in range(13):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'axis'

# %%
""" VIDEO FUNCTIONS FOR CHECKING POST TRAINING"""

def get_mask(model,l=0):
    b = binarize(model.layers[l].weights[0])
    figb,axb = plt.subplots(1,1)
    axb.imshow(np.reshape(b,(32,32)),cmap="gray")
    
def show_video(y_pred,y_true,num):
    yp = np.reshape(y_pred,(-1,30,32,32))
    yt = np.reshape(y_true,(-1,30,32,32))
    yp_tensor = tf.convert_to_tensor(y_pred)
    yt_tensor = tf.convert_to_tensor(y_true)
    ssim = np.mean(ssim_loss(yt_tensor[num],yp_tensor[num]))
    mse = np.mean(mse_loss(yt_tensor[num],yp_tensor[num]))
    fig,ax = plt.subplots(nrows=5,ncols=6,sharex=True,sharey=True)
    fig.suptitle(f'Movie: {num} MSE: {mse} SSIM: {ssim}')
    fig2,ax2 = plt.subplots(nrows=5,ncols=6,sharex=True,sharey=True)
    for row in range(5):
        for col in range(6):
            ax[row,col].imshow(yp[num][5*row+col],cmap="gray")
            ax2[row,col].imshow(yt[num][5*row+col],cmap="gray")
            
            
def show_video2(y_pred,y_true,num):
    yp = np.reshape(y_pred,(-1,30,32,32))
    yt = np.reshape(y_true,(-1,30,32,32))
    split = np.zeros((5,32,32))
    yp_tensor = tf.convert_to_tensor(y_pred)
    yt_tensor = tf.convert_to_tensor(y_true)
    ssim = np.mean(ssim_loss(yt_tensor[num],yp_tensor[num]))
    mse = np.mean(mse_loss(yt_tensor[num],yp_tensor[num]))
    fig,ax = plt.subplots(nrows=5,ncols=13,sharex=True,sharey=True)
    fig.suptitle(f'Movie: {num} MSE: {mse} SSIM: {ssim}')
    for row in range(5):
        for col in range(13):
            if col < 6:
                ax[row,col].imshow(yp[num][5*row+col],cmap="gray")
            elif col == 6:
                pass
            else:
                ax[row,col].imshow(yt[num][5*row + (col %6)],cmap="gray")
    


def show_all_videos(videos,rows,cols):
    yp = np.reshape(videos, (-1,30,32,32))
    fix3,ax3 = plt.subplots(nrows=rows, ncols = cols)
    for row in range(rows):
        for col in range(cols):
            ax3[row,col].imshow(yp[rows*row+col][3],cmap="gray")

# %%
""" FORWARD MODEL """

forward_model = Sequential()
forward_model.add(Input(shape=(30,32,32,1),batch_size = 32))
forward_model.add(TimeDistributed(BinaryConv2D(1, kernel_size=(32,32), input_shape=(30,32,32,1),
                       data_format='channels_last',
                       H=H, kernel_lr_multiplier=kernel_lr_multiplier,
                       padding='same', use_bias=use_bias, name='bin_conv_1')))
forward_model.add(Reshape((30,32,32)))
forward_model.add(Lambda(streak,output_shape=streak_output_shape))
forward_model.add(Lambda(integrate_ims, output_shape = integrate_ims_output_shape))
forward_model.add(Flatten())
forward_model.add(Dense(30720, activation = 'relu'))
forward_model.add(Reshape((30,32,32,1)))
forward_model.compile(optimizer = Nadam(0.0001), loss = custom_loss, metrics = ['mean_squared_error',mse_loss])
forward_model.summary()
# Out:
# (32, 30, 62, 32)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (32, 30, 32, 32, 1)       1024
# _________________________________________________________________
# reshape (Reshape)            (32, 30, 32, 32)          0
# _________________________________________________________________
# lambda (Lambda)              (32, 30, 62, 32)          0
# _________________________________________________________________
# lambda_1 (Lambda)            (32, 62, 32)              0
# _________________________________________________________________
# flatten (Flatten)            (32, 1984)                0
# _________________________________________________________________
# dense (Dense)                (32, 30720)               60979200
# _________________________________________________________________
# reshape_1 (Reshape)          (32, 30, 32, 32, 1)       0
# =================================================================
# Total params: 60,980,224
# Trainable params: 60,980,224
# Non-trainable params: 0
# _________________________________________________________________

# %%
forward_model.load_weights('../data/model_stuff/forward_weights_4_12.h5')
binary_weights = forward_model.layers[0].get_weights()
inverse_weights = forward_model.layers[5].get_weights()

# %%
""" 
UNET MODEL
Fixing the weights for the bin_conv1 layer as well as the dense1 layer, ie NON TRAINABLE
Feeding in weights from the forward_model above to see if that improves the results from previous session

"""
inputs = Input(shape=(30,32,32,1))
bin_conv1 = TimeDistributed(BinaryConv2D(1, kernel_size=(32,32), input_shape=(30,32,32,1),
                       data_format='channels_last',
                       H=H, kernel_lr_multiplier=kernel_lr_multiplier,
                       padding='same', use_bias=use_bias, name='bin_conv_1',trainable=False))(inputs)
resh1 = Reshape((30,32,32))(bin_conv1)
s = Lambda(streak, output_shape = streak_output_shape)(resh1)
i = Lambda(integrate_ims, output_shape = integrate_ims_output_shape) (s)
f = Flatten()(i)
dense1 = Dense(30720, activation = 'relu',trainable=False)(f)
resh2 = Reshape((30,32,32,1))(dense1)
c1 = TimeDistributed(Conv2D(1, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (resh2)
c1 = Dropout(0.1) (c1)
c1 = TimeDistributed(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c1)
p1 = TimeDistributed(MaxPooling2D((2, 2)))(c1)

c2 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))(p1)
c2 = Dropout(0.1) (c2)
c2 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c2)
p2 = TimeDistributed(MaxPooling2D((2, 2)) )(c2)

c3 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(p2)
c3 = Dropout(0.2) (c3)
c3 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c3)
p3 = TimeDistributed(MaxPooling2D((2, 2)) )(c3)
    
c4 = TimeDistributed(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(p3)
c4 = Dropout(0.2) (c4)
c4 = TimeDistributed(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c4)
p4 = TimeDistributed(MaxPooling2D(pool_size=(2, 2))) (c4)

c5 = TimeDistributed(Conv2D(256, (2, 2), activation='relu', kernel_initializer='he_normal', padding='same')) (p4)
c5 = Dropout(0.3) (c5)
c5 = TimeDistributed(Conv2D(256, (2, 2), activation='relu', kernel_initializer='he_normal', padding='same')) (c5)

u6 = TimeDistributed(Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same'))(c5)
u6 = concatenate([u6, c4])
c6 = TimeDistributed( Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(u6)
c6 = Dropout(0.2) (c6)
c6 = TimeDistributed(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c6)

u7 = TimeDistributed(Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same') )(c6)
u7 = concatenate([u7, c3])
c7 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (u7)
c7 = Dropout(0.2) (c7)
c7 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c7)
    
u8 = TimeDistributed(Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same') )(c7)
u8 = concatenate([u8, c2])
c8 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (u8)
c8 = Dropout(0.1) (c8)
c8 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c8)

u9 = TimeDistributed(Conv2DTranspose(16, (3, 3), strides=(2, 2), padding='same')) (c8)
c9 = TimeDistributed(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (u9)
c9 = Dropout(0.1) (c9)
c9 = TimeDistributed(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c9)
    
outputs = TimeDistributed(Conv2D(1, (1, 1), activation='sigmoid')) (c9)

CUPNET = Model(inputs = [inputs], outputs = [outputs])
    
CUPNET.compile(optimizer = Nadam(), loss = custom_loss, metrics = ['mean_squared_error'])
# Out:
# (None, 30, 62, 32)

# %%
CUPNET.load_weights('../data/model_stuff/cupnet_model_4_12.h5')

# %%
""" SET THE PREFIXED WEIGHTS FROM THE FORWARD MODEL """
CUPNET.layers[1].set_weights(binary_weights)
CUPNET.layers[6].set_weights(inverse_weights)
CUPNET.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 30, 32, 32,  0
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 30, 32, 32, 1 1024        input_2[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 30, 32, 32)   0           time_distributed_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 30, 62, 32)   0           reshape_2[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 62, 32)       0           lambda_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1984)         0           lambda_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30720)        60979200    flatten_1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 30, 32, 32, 1 0           dense_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 30, 32, 32, 1 10          reshape_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 30, 32, 32, 1 0           time_distributed_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 30, 32, 32, 1 160         dropout[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 30, 16, 16, 1 0           time_distributed_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 30, 16, 16, 3 4640        time_distributed_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 30, 16, 16, 3 0           time_distributed_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 30, 16, 16, 3 9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 30, 8, 8, 32) 0           time_distributed_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 30, 8, 8, 64) 18496       time_distributed_7[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 30, 8, 8, 64) 0           time_distributed_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 30, 8, 8, 64) 36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 30, 4, 4, 64) 0           time_distributed_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 30, 4, 4, 128 73856       time_distributed_10[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 30, 4, 4, 128 0           time_distributed_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 30, 4, 4, 128 147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 30, 2, 2, 128 0           time_distributed_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 30, 2, 2, 256 131328      time_distributed_13[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 30, 2, 2, 256 0           time_distributed_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 30, 2, 2, 256 262400      dropout_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 30, 4, 4, 128 295040      time_distributed_15[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 30, 4, 4, 256 0           time_distributed_16[0][0]
#                                                                  time_distributed_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 30, 4, 4, 128 295040      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 30, 4, 4, 128 0           time_distributed_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 30, 4, 4, 128 147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 30, 8, 8, 64) 73792       time_distributed_18[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 8, 8, 128 0           time_distributed_19[0][0]
#                                                                  time_distributed_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 30, 8, 8, 64) 73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 30, 8, 8, 64) 0           time_distributed_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 30, 8, 8, 64) 36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 30, 16, 16, 3 18464       time_distributed_21[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 30, 16, 16, 6 0           time_distributed_22[0][0]
#                                                                  time_distributed_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 30, 16, 16, 3 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 30, 16, 16, 3 0           time_distributed_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 30, 16, 16, 3 9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 30, 32, 32, 1 4624        time_distributed_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 30, 32, 32, 1 2320        time_distributed_25[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 30, 32, 32, 1 0           time_distributed_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 30, 32, 32, 1 2320        dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 30, 32, 32, 1 17          time_distributed_27[0][0]
# ==================================================================================================
# Total params: 62,642,507
# Trainable params: 1,662,283
# Non-trainable params: 60,980,224
# __________________________________________________________________________________________________

# %%
""" CUPNET TRAINING """
CUPNET_history = CUPNET.fit(MX_train, My_train,
          batch_size = 32,epochs= 500,
          verbose=2,validation_data=(MX_test,My_test),callbacks=[reduce_lr])
# Out:
# Train on 1050 samples, validate on 450 samples
# Epoch 1/500
# 1050/1050 - 32s - loss: 0.2215 - mean_squared_error: 0.0600 - val_loss: 0.2142 - val_mean_squared_error: 0.0506
# Epoch 2/500
# 1050/1050 - 15s - loss: 0.1819 - mean_squared_error: 0.0296 - val_loss: 0.1916 - val_mean_squared_error: 0.0303
# Epoch 3/500
# 1050/1050 - 15s - loss: 0.1678 - mean_squared_error: 0.0242 - val_loss: 0.1838 - val_mean_squared_error: 0.0251
# Epoch 4/500
# 1050/1050 - 15s - loss: 0.1594 - mean_squared_error: 0.0218 - val_loss: 0.1740 - val_mean_squared_error: 0.0206
# Epoch 5/500
# 1050/1050 - 15s - loss: 0.1523 - mean_squared_error: 0.0198 - val_loss: 0.1743 - val_mean_squared_error: 0.0208
# Epoch 6/500
# 1050/1050 - 15s - loss: 0.1439 - mean_squared_error: 0.0172 - val_loss: 0.1691 - val_mean_squared_error: 0.0190
# Epoch 7/500
# 1050/1050 - 15s - loss: 0.1379 - mean_squared_error: 0.0157 - val_loss: 0.1662 - val_mean_squared_error: 0.0183
# Epoch 8/500
# 1050/1050 - 15s - loss: 0.1324 - mean_squared_error: 0.0147 - val_loss: 0.1657 - val_mean_squared_error: 0.0176
# Epoch 9/500
# 1050/1050 - 15s - loss: 0.1297 - mean_squared_error: 0.0144 - val_loss: 0.1623 - val_mean_squared_error: 0.0167
# Epoch 10/500
# 1050/1050 - 15s - loss: 0.1273 - mean_squared_error: 0.0138 - val_loss: 0.1670 - val_mean_squared_error: 0.0184
# Epoch 11/500
# 1050/1050 - 15s - loss: 0.1248 - mean_squared_error: 0.0132 - val_loss: 0.1649 - val_mean_squared_error: 0.0187
# Epoch 12/500
# 1050/1050 - 15s - loss: 0.1228 - mean_squared_error: 0.0132 - val_loss: 0.1619 - val_mean_squared_error: 0.0168
# Epoch 13/500
# 1050/1050 - 15s - loss: 0.1212 - mean_squared_error: 0.0126 - val_loss: 0.1630 - val_mean_squared_error: 0.0182
# Epoch 14/500
# 1050/1050 - 15s - loss: 0.1194 - mean_squared_error: 0.0124 - val_loss: 0.1611 - val_mean_squared_error: 0.0167
# Epoch 15/500
# 1050/1050 - 15s - loss: 0.1178 - mean_squared_error: 0.0121 - val_loss: 0.1614 - val_mean_squared_error: 0.0173
# Epoch 16/500
# 1050/1050 - 15s - loss: 0.1199 - mean_squared_error: 0.0126 - val_loss: 0.1608 - val_mean_squared_error: 0.0163
# Epoch 17/500
# 1050/1050 - 15s - loss: 0.1154 - mean_squared_error: 0.0115 - val_loss: 0.1595 - val_mean_squared_error: 0.0155
# Epoch 18/500
# 1050/1050 - 15s - loss: 0.1150 - mean_squared_error: 0.0117 - val_loss: 0.1593 - val_mean_squared_error: 0.0163
# Epoch 19/500
# 1050/1050 - 15s - loss: 0.1132 - mean_squared_error: 0.0111 - val_loss: 0.1594 - val_mean_squared_error: 0.0155
# Epoch 20/500
# 1050/1050 - 15s - loss: 0.1140 - mean_squared_error: 0.0116 - val_loss: 0.1596 - val_mean_squared_error: 0.0164
# Epoch 21/500
# 1050/1050 - 15s - loss: 0.1136 - mean_squared_error: 0.0116 - val_loss: 0.1589 - val_mean_squared_error: 0.0160
# Epoch 22/500
# 1050/1050 - 15s - loss: 0.1129 - mean_squared_error: 0.0113 - val_loss: 0.1592 - val_mean_squared_error: 0.0153
# Epoch 23/500
# 1050/1050 - 15s - loss: 0.1114 - mean_squared_error: 0.0111 - val_loss: 0.1580 - val_mean_squared_error: 0.0152
# Epoch 24/500
# 1050/1050 - 15s - loss: 0.1105 - mean_squared_error: 0.0111 - val_loss: 0.1607 - val_mean_squared_error: 0.0179
# Epoch 25/500
# 1050/1050 - 15s - loss: 0.1099 - mean_squared_error: 0.0109 - val_loss: 0.1588 - val_mean_squared_error: 0.0157
# Epoch 26/500
# 1050/1050 - 15s - loss: 0.1098 - mean_squared_error: 0.0112 - val_loss: 0.1585 - val_mean_squared_error: 0.0154
# Epoch 27/500
# 1050/1050 - 15s - loss: 0.1086 - mean_squared_error: 0.0107 - val_loss: 0.1564 - val_mean_squared_error: 0.0152
# Epoch 28/500
# 1050/1050 - 15s - loss: 0.1080 - mean_squared_error: 0.0106 - val_loss: 0.1610 - val_mean_squared_error: 0.0167
# Epoch 29/500
# 1050/1050 - 15s - loss: 0.1093 - mean_squared_error: 0.0109 - val_loss: 0.1598 - val_mean_squared_error: 0.0173
# Epoch 30/500
# 1050/1050 - 15s - loss: 0.1072 - mean_squared_error: 0.0108 - val_loss: 0.1578 - val_mean_squared_error: 0.0153
# Epoch 31/500
# 1050/1050 - 15s - loss: 0.1065 - mean_squared_error: 0.0105 - val_loss: 0.1564 - val_mean_squared_error: 0.0149
# Epoch 32/500
# 1050/1050 - 15s - loss: 0.1076 - mean_squared_error: 0.0107 - val_loss: 0.1575 - val_mean_squared_error: 0.0157
# Epoch 33/500
# 1050/1050 - 15s - loss: 0.1058 - mean_squared_error: 0.0104 - val_loss: 0.1581 - val_mean_squared_error: 0.0161
# Epoch 34/500
# 1050/1050 - 15s - loss: 0.1055 - mean_squared_error: 0.0105 - val_loss: 0.1582 - val_mean_squared_error: 0.0159
# Epoch 35/500
# 1050/1050 - 15s - loss: 0.1053 - mean_squared_error: 0.0102 - val_loss: 0.1563 - val_mean_squared_error: 0.0152
# Epoch 36/500
# 1050/1050 - 15s - loss: 0.1041 - mean_squared_error: 0.0102 - val_loss: 0.1577 - val_mean_squared_error: 0.0152
# Epoch 37/500
# 1050/1050 - 15s - loss: 0.1043 - mean_squared_error: 0.0103 - val_loss: 0.1568 - val_mean_squared_error: 0.0152
# Epoch 38/500
# 1050/1050 - 15s - loss: 0.1038 - mean_squared_error: 0.0102 - val_loss: 0.1564 - val_mean_squared_error: 0.0156
# Epoch 39/500
# 1050/1050 - 15s - loss: 0.1028 - mean_squared_error: 0.0098 - val_loss: 0.1569 - val_mean_squared_error: 0.0156
# Epoch 40/500
# 1050/1050 - 15s - loss: 0.1029 - mean_squared_error: 0.0101 - val_loss: 0.1582 - val_mean_squared_error: 0.0156
# Epoch 41/500
# 1050/1050 - 15s - loss: 0.1025 - mean_squared_error: 0.0100 - val_loss: 0.1571 - val_mean_squared_error: 0.0157
# Epoch 42/500
# 1050/1050 - 15s - loss: 0.1016 - mean_squared_error: 0.0098 - val_loss: 0.1555 - val_mean_squared_error: 0.0147
# Epoch 43/500
# 1050/1050 - 15s - loss: 0.1015 - mean_squared_error: 0.0098 - val_loss: 0.1581 - val_mean_squared_error: 0.0159
# Epoch 44/500
# 1050/1050 - 15s - loss: 0.1018 - mean_squared_error: 0.0101 - val_loss: 0.1560 - val_mean_squared_error: 0.0155
# Epoch 45/500
# 1050/1050 - 15s - loss: 0.1010 - mean_squared_error: 0.0099 - val_loss: 0.1564 - val_mean_squared_error: 0.0155
# Epoch 46/500
# 1050/1050 - 15s - loss: 0.1007 - mean_squared_error: 0.0098 - val_loss: 0.1561 - val_mean_squared_error: 0.0149
# Epoch 47/500
# 1050/1050 - 15s - loss: 0.1000 - mean_squared_error: 0.0095 - val_loss: 0.1563 - val_mean_squared_error: 0.0149
# Epoch 48/500
# 1050/1050 - 15s - loss: 0.1000 - mean_squared_error: 0.0096 - val_loss: 0.1563 - val_mean_squared_error: 0.0151
# Epoch 49/500
# 1050/1050 - 15s - loss: 0.1003 - mean_squared_error: 0.0100 - val_loss: 0.1562 - val_mean_squared_error: 0.0154
# Epoch 50/500
# 1050/1050 - 15s - loss: 0.0992 - mean_squared_error: 0.0095 - val_loss: 0.1571 - val_mean_squared_error: 0.0153
# Epoch 51/500
# 1050/1050 - 15s - loss: 0.0984 - mean_squared_error: 0.0094 - val_loss: 0.1555 - val_mean_squared_error: 0.0153
# Epoch 52/500
# 1050/1050 - 15s - loss: 0.0985 - mean_squared_error: 0.0097 - val_loss: 0.1556 - val_mean_squared_error: 0.0148
# Epoch 53/500
# 1050/1050 - 15s - loss: 0.0982 - mean_squared_error: 0.0096 - val_loss: 0.1559 - val_mean_squared_error: 0.0152
# Epoch 54/500
# 1050/1050 - 15s - loss: 0.0974 - mean_squared_error: 0.0092 - val_loss: 0.1548 - val_mean_squared_error: 0.0146
# Epoch 55/500
# 1050/1050 - 15s - loss: 0.0981 - mean_squared_error: 0.0096 - val_loss: 0.1604 - val_mean_squared_error: 0.0152
# Epoch 56/500
# 1050/1050 - 15s - loss: 0.0976 - mean_squared_error: 0.0095 - val_loss: 0.1561 - val_mean_squared_error: 0.0148
# Epoch 57/500
# 1050/1050 - 15s - loss: 0.0966 - mean_squared_error: 0.0092 - val_loss: 0.1562 - val_mean_squared_error: 0.0152
# Epoch 58/500
# 1050/1050 - 15s - loss: 0.0963 - mean_squared_error: 0.0092 - val_loss: 0.1552 - val_mean_squared_error: 0.0148
# Epoch 59/500
# 1050/1050 - 15s - loss: 0.0959 - mean_squared_error: 0.0090 - val_loss: 0.1570 - val_mean_squared_error: 0.0159
# Epoch 60/500
# 1050/1050 - 15s - loss: 0.0974 - mean_squared_error: 0.0097 - val_loss: 0.1554 - val_mean_squared_error: 0.0147
# Epoch 61/500
# 1050/1050 - 15s - loss: 0.0950 - mean_squared_error: 0.0090 - val_loss: 0.1565 - val_mean_squared_error: 0.0152
# Epoch 62/500
# 1050/1050 - 15s - loss: 0.0962 - mean_squared_error: 0.0095 - val_loss: 0.1552 - val_mean_squared_error: 0.0147
# Epoch 63/500
# 1050/1050 - 15s - loss: 0.0947 - mean_squared_error: 0.0089 - val_loss: 0.1547 - val_mean_squared_error: 0.0147
# Epoch 64/500
# 1050/1050 - 15s - loss: 0.0946 - mean_squared_error: 0.0089 - val_loss: 0.1551 - val_mean_squared_error: 0.0148
# Epoch 65/500
# 1050/1050 - 15s - loss: 0.0950 - mean_squared_error: 0.0092 - val_loss: 0.1562 - val_mean_squared_error: 0.0148
# Epoch 66/500
# 1050/1050 - 15s - loss: 0.0944 - mean_squared_error: 0.0091 - val_loss: 0.1560 - val_mean_squared_error: 0.0151
# Epoch 67/500
# 1050/1050 - 15s - loss: 0.0939 - mean_squared_error: 0.0089 - val_loss: 0.1563 - val_mean_squared_error: 0.0151
# Epoch 68/500
# 1050/1050 - 15s - loss: 0.0942 - mean_squared_error: 0.0091 - val_loss: 0.1562 - val_mean_squared_error: 0.0150
# Epoch 69/500
# 1050/1050 - 15s - loss: 0.0936 - mean_squared_error: 0.0091 - val_loss: 0.1565 - val_mean_squared_error: 0.0149
# Epoch 70/500
# 1050/1050 - 15s - loss: 0.0926 - mean_squared_error: 0.0087 - val_loss: 0.1559 - val_mean_squared_error: 0.0150
# Epoch 71/500
# 1050/1050 - 15s - loss: 0.0937 - mean_squared_error: 0.0090 - val_loss: 0.1558 - val_mean_squared_error: 0.0148
# Epoch 72/500
# 1050/1050 - 15s - loss: 0.0930 - mean_squared_error: 0.0090 - val_loss: 0.1552 - val_mean_squared_error: 0.0149
# Epoch 73/500
# 1050/1050 - 15s - loss: 0.0926 - mean_squared_error: 0.0088 - val_loss: 0.1563 - val_mean_squared_error: 0.0155
# Epoch 74/500
# 1050/1050 - 15s - loss: 0.0925 - mean_squared_error: 0.0089 - val_loss: 0.1556 - val_mean_squared_error: 0.0149
# Epoch 75/500
# 1050/1050 - 15s - loss: 0.0919 - mean_squared_error: 0.0086 - val_loss: 0.1574 - val_mean_squared_error: 0.0153
# Epoch 76/500
# 1050/1050 - 15s - loss: 0.0919 - mean_squared_error: 0.0088 - val_loss: 0.1563 - val_mean_squared_error: 0.0152
# Epoch 77/500
# 1050/1050 - 15s - loss: 0.0924 - mean_squared_error: 0.0087 - val_loss: 0.1561 - val_mean_squared_error: 0.0150
# Epoch 78/500
# 1050/1050 - 15s - loss: 0.0908 - mean_squared_error: 0.0085 - val_loss: 0.1559 - val_mean_squared_error: 0.0149
# Epoch 79/500
# 1050/1050 - 15s - loss: 0.0910 - mean_squared_error: 0.0086 - val_loss: 0.1556 - val_mean_squared_error: 0.0149
# Epoch 80/500
# 1050/1050 - 15s - loss: 0.0913 - mean_squared_error: 0.0086 - val_loss: 0.1581 - val_mean_squared_error: 0.0156
# Epoch 81/500
# 1050/1050 - 15s - loss: 0.0905 - mean_squared_error: 0.0085 - val_loss: 0.1553 - val_mean_squared_error: 0.0149
# Epoch 82/500
# 1050/1050 - 15s - loss: 0.0907 - mean_squared_error: 0.0087 - val_loss: 0.1557 - val_mean_squared_error: 0.0150
# Epoch 83/500
# 1050/1050 - 15s - loss: 0.0897 - mean_squared_error: 0.0084 - val_loss: 0.1554 - val_mean_squared_error: 0.0149
# Epoch 84/500
# 1050/1050 - 15s - loss: 0.0900 - mean_squared_error: 0.0086 - val_loss: 0.1558 - val_mean_squared_error: 0.0149
# Epoch 85/500
# 1050/1050 - 15s - loss: 0.0904 - mean_squared_error: 0.0086 - val_loss: 0.1560 - val_mean_squared_error: 0.0149
# Epoch 86/500
# 1050/1050 - 15s - loss: 0.0893 - mean_squared_error: 0.0084 - val_loss: 0.1554 - val_mean_squared_error: 0.0149
# Epoch 87/500
# 1050/1050 - 15s - loss: 0.0890 - mean_squared_error: 0.0083 - val_loss: 0.1563 - val_mean_squared_error: 0.0151
# Epoch 88/500
# 1050/1050 - 15s - loss: 0.0901 - mean_squared_error: 0.0087 - val_loss: 0.1557 - val_mean_squared_error: 0.0149
# Epoch 89/500
# 1050/1050 - 15s - loss: 0.0888 - mean_squared_error: 0.0084 - val_loss: 0.1585 - val_mean_squared_error: 0.0167
# Epoch 90/500
# 1050/1050 - 15s - loss: 0.0886 - mean_squared_error: 0.0083 - val_loss: 0.1571 - val_mean_squared_error: 0.0160
# Epoch 91/500
# 1050/1050 - 15s - loss: 0.0897 - mean_squared_error: 0.0085 - val_loss: 0.1567 - val_mean_squared_error: 0.0150
# Epoch 92/500
# 1050/1050 - 15s - loss: 0.0885 - mean_squared_error: 0.0083 - val_loss: 0.1552 - val_mean_squared_error: 0.0147
# Epoch 93/500
# 1050/1050 - 15s - loss: 0.0886 - mean_squared_error: 0.0084 - val_loss: 0.1560 - val_mean_squared_error: 0.0150
# Epoch 94/500
# 1050/1050 - 15s - loss: 0.0882 - mean_squared_error: 0.0083 - val_loss: 0.1570 - val_mean_squared_error: 0.0158
# Epoch 95/500
# 1050/1050 - 15s - loss: 0.0880 - mean_squared_error: 0.0082 - val_loss: 0.1573 - val_mean_squared_error: 0.0157
# Epoch 96/500
# 1050/1050 - 15s - loss: 0.0882 - mean_squared_error: 0.0085 - val_loss: 0.1556 - val_mean_squared_error: 0.0148
# Epoch 97/500
# 1050/1050 - 15s - loss: 0.0869 - mean_squared_error: 0.0080 - val_loss: 0.1567 - val_mean_squared_error: 0.0150
# Epoch 98/500
# 1050/1050 - 15s - loss: 0.0870 - mean_squared_error: 0.0081 - val_loss: 0.1576 - val_mean_squared_error: 0.0164
# Epoch 99/500
# 1050/1050 - 15s - loss: 0.0874 - mean_squared_error: 0.0082 - val_loss: 0.1558 - val_mean_squared_error: 0.0149
# Epoch 100/500
# 1050/1050 - 15s - loss: 0.0871 - mean_squared_error: 0.0082 - val_loss: 0.1594 - val_mean_squared_error: 0.0161
# Epoch 101/500
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error,lr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-454358666326> in <module>
#       2 CUPNET_history = CUPNET.fit(MX_train, My_train,
#       3           batch_size = 32,epochs= 500,
# ----> 4           verbose=2,validation_data=(MX_test,My_test),callbacks=[reduce_lr])
#       5
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     455
#     456     tracing_count = self._get_tracing_count()
# --> 457     result = self._call(*args, **kwds)
#     458     if tracing_count == self._get_tracing_count():
#     459       self._call_counter.called_without_tracing()
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     485       # In this case we have created variables on the first call, so we run the
#     486       # defunned version which is guaranteed to never create variables.
# --> 487       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     488     elif self._stateful_fn is not None:
#     489       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1821     """Calls a graph function specialized to the inputs."""
#    1822     graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 1823     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    1824
#    1825   @property
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1139          if isinstance(t, (ops.Tensor,
#    1140                            resource_variable_ops.BaseResourceVariable))),
# -> 1141         self.captured_inputs)
#    1142
#    1143   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
CUPNET.save_weights("../data/model_stuff/cupnet_model_4_12.h5")

# %%
y_pred = CUPNET.predict(MX_test)

# %%
show_video(y_pred,My_test,30)

# %%
fig,ax = plt.subplots(1,1)
ax.imshow(np.reshape(ims2,(-1,62,32))[30],cmap="gray")

# %%
fig1,ax1 = plt.subplots(1,1)
ax1.imshow(np.reshape(validate2,(-1,30,32,32))[50][10],cmap="gray")

# %%
fig2,ax2=plt.subplots(1,1)
ax2.imshow(np.reshape(validate,(-1,30,32,32))[50][10],cmap="gray")
