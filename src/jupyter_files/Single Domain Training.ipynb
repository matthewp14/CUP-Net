# %%
"""
Created on Wed Feb 26 17:01:56 2020

"""

""" IMPORTS """
import sys
import numpy as np
sys.path.append("../")
np.random.seed(1337)  # for reproducibility
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.datasets import mnist
from tensorflow.keras.constraints import *
from sklearn.model_selection import train_test_split
# from keras.utils import np_utils

from binary_ops import binary_tanh as binary_tanh_op
from binary_layers import BinaryDense, BinaryConv2D

import h5py
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
from lambda_layers import *
from binary_ops import *
# %matplotlib qt

# %%
""" FUNCTIION AND VARIABLE DEFINITIONS """
def binary_tanh(x):
    return binary_tanh_op(x)

H = 1.
kernel_lr_multiplier = 'Glorot'

# # nn
batch_size = 50
epochs = 20
channels = 1
img_rows = 30
img_cols = 30
filters = 32
kernel_size = (32, 32)
pool_size = (2, 2)
hidden_units = 128
classes = 10
use_bias = False

# # learning rate schedule
lr_start = 1e-3
lr_end = 1e-4
lr_decay = (lr_end / lr_start)**(1. / epochs)

# # BN
epsilon = 1e-6
momentum = 0.9

# # dropout
p1 = 0.25
p2 = 0.5

hdf5_dir = Path("../../data/hdf5/")

def read_many_hdf5(num_images):
    """ Reads image from HDF5.
        Parameters:
        ---------------
        num_images   number of images to read
        Returns:
        ----------
        images      images array, (N, 32, 32, 3) to be stored
        labels      associated meta data, int label (N, 1)
    """
    images= []

    # Open the HDF5 file
    file = h5py.File(hdf5_dir / f"{num_images}_vids.h5", "r+")

    images = np.array(file["/images"]).astype("float32")

    return images

def np_streak(x):
    input_dims = np.shape(x)
    output_shape = (input_dims[0],input_dims[1],input_dims[1]+input_dims[2],input_dims[3],input_dims[4])
    streak_tensor = np.zeros(output_shape)
    for i in range(output_shape[0]):
        for j in range(output_shape[1]):
            streak_tensor[i,j,j:(output_shape[3]+j),:,:] = x[i,j,:,:,:]
    #return streak_tensor
    return np.sum(streak_tensor,axis=1)

def mask(val,ims,mask):
    for i in range(np.shape(val)[0]):
        for j in range(np.shape(val)[1]):
            val[i,j,:,:] = ims[i,j,:,:] * mask
    return val



jelly1 = read_many_hdf5("jelly")
jelly2 = read_many_hdf5("jelly_2")
ims = np.concatenate((jelly1,jelly2))
ims = np.reshape(ims,(-1,30,32,32,1))

validate = ims

validate = validate / 255
#ims2 = ims2 /255
ims = ims/255
#X_train, X_test, y_train, y_test = train_test_split(ims, validate, test_size=(1/3), random_state=42)
#X_train, X_test, y_train, y_test = train_test_split(ims2, validate, test_size=(1/3), random_state=42)

MX_train, MX_test, My_train, My_test = train_test_split(ims,ims, test_size = 0.3, random_state = 42)

print(np.shape(MX_test))
print(np.shape(MX_train))


reduce_lr = ReduceLROnPlateau(monitor='val_loss',verbose=1, factor=0.5,
                              patience=25, min_lr=0.000001)
early_stopping = EarlyStopping(patience=50,verbose=1,restore_best_weights=True)   


def custom_loss(y_true, y_pred):

  ssim_loss = (1.0-tf.image.ssim(y_true,y_pred,1))/2.0
  mse_loss = K.mean(K.square(y_pred-y_true))
  #mse_loss = tf.keras.losses.mean_squared_error(y_true,y_pred)

  ssim_loss = 0.5*ssim_loss
  mse_loss = 0.5*mse_loss

  return ssim_loss + mse_loss

def ssim_loss(y_true,y_pred):  
    return (1.0-tf.image.ssim(y_true,y_pred,1))/2.0

def mse_loss(y_true,y_pred):
    return K.mean(K.square(y_pred-y_true))
# Out:
# (381, 30, 32, 32, 1)
# (888, 30, 32, 32, 1)

# %%
""" VIDEO FUNCTIONS FOR CHECKING POST TRAINING"""

def get_mask(model,l=0, save = False, filename = "mask"):
    b = binarize(model.layers[l].weights[0])
    figb,axb = plt.subplots(1,1)
    axb.imshow(np.reshape(b,(32,32)),cmap="gray")
    
    if save:
        b = np.reshape(b,(32,32))
        np.save(filename,b)
                            
def show_video(y_pred,y_true,num,save=False):
    yp = np.reshape(y_pred,(-1,30,32,32))
    yt = np.reshape(y_true,(-1,30,32,32))
    split = np.zeros((5,32,32))
    yp_tensor = tf.convert_to_tensor(y_pred)
    yt_tensor = tf.convert_to_tensor(y_true)
    ssim = np.mean(ssim_loss(yt_tensor[num],yp_tensor[num]))
    mse = np.mean(mse_loss(yt_tensor[num],yp_tensor[num]))
    fig,ax = plt.subplots(nrows=5,ncols=13,figsize=(21,10),sharex=True,sharey=True)
    fig.suptitle(f'Movie: {num} MSE: {mse:.3} SSIM: {ssim:.3}')
    for row in range(5):
        for col in range(13):
            if col < 6:
                ax[row,col].imshow(yp[num][5*row+col],cmap="gray")
            elif col == 6:
                pass
            else:
                ax[row,col].imshow(yt[num][5*row + (col %6)],cmap="gray")
    if save:
        fig.savefig('test.png')

def show_all_videos(videos,rows,cols):
    yp = np.reshape(videos, (-1,30,32,32))
    fix3,ax3 = plt.subplots(nrows=rows, ncols = cols)
    for row in range(rows):
        for col in range(cols):
            ax3[row,col].imshow(yp[rows*row+col][3],cmap="gray")

# %%
""" FORWARD MODEL """

forward_model = Sequential()
forward_model.add(Input(shape=(30,32,32,1)))
forward_model.add(TimeDistributed(BinaryConv2D(1, kernel_size=(32,32), input_shape=(30,32,32,1),
                   data_format='channels_last',
                   H=H, kernel_lr_multiplier=kernel_lr_multiplier,
                   padding='same', use_bias=use_bias, name='bin_conv_1')))
forward_model.add(Reshape((30,32,32)))
forward_model.add(Lambda(streak,output_shape=streak_output_shape))
forward_model.add(Lambda(integrate_ims, output_shape = integrate_ims_output_shape))
forward_model.add(Flatten())
forward_model.add(Dense(30720, activation = 'relu'))
forward_model.add(Reshape((30,32,32,1)))
forward_model.compile(optimizer = Nadam(0.0001), loss = custom_loss, metrics = [ssim_loss,mse_loss])
forward_model.summary()
forward_history = forward_model.fit(MX_train, My_train,
      batch_size = 32,epochs= 100,
    verbose=2,validation_data=(MX_test,My_test),callbacks=[reduce_lr, early_stopping])
# Out:
# (None, 30, 62, 32)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 30, 32, 32, 1)     1024
# _________________________________________________________________
# reshape (Reshape)            (None, 30, 32, 32)        0
# _________________________________________________________________
# lambda (Lambda)              (None, 30, 62, 32)        0
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 62, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1984)              0
# _________________________________________________________________
# dense (Dense)                (None, 30720)             60979200
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 30, 32, 32, 1)     0
# =================================================================
# Total params: 60,980,224
# Trainable params: 60,980,224
# Non-trainable params: 0
# _________________________________________________________________
# Train on 888 samples, validate on 381 samples
# Epoch 1/100
# 888/888 - 11s - loss: 0.2956 - ssim_loss: 0.4888 - mse_loss: 0.1021 - val_loss: 0.2812 - val_ssim_loss: 0.4874 - val_mse_loss: 0.0749
# Epoch 2/100
# 888/888 - 5s - loss: 0.2824 - ssim_loss: 0.4869 - mse_loss: 0.0777 - val_loss: 0.2809 - val_ssim_loss: 0.4871 - val_mse_loss: 0.0746
# Epoch 3/100
# 888/888 - 5s - loss: 0.2839 - ssim_loss: 0.4868 - mse_loss: 0.0812 - val_loss: 0.2836 - val_ssim_loss: 0.4867 - val_mse_loss: 0.0804
# Epoch 4/100
# 888/888 - 5s - loss: 0.2854 - ssim_loss: 0.4867 - mse_loss: 0.0841 - val_loss: 0.2849 - val_ssim_loss: 0.4876 - val_mse_loss: 0.0820
# Epoch 5/100
# 888/888 - 5s - loss: 0.2862 - ssim_loss: 0.4868 - mse_loss: 0.0857 - val_loss: 0.2854 - val_ssim_loss: 0.4861 - val_mse_loss: 0.0847
# Epoch 6/100
# 888/888 - 5s - loss: 0.2870 - ssim_loss: 0.4867 - mse_loss: 0.0873 - val_loss: 0.2856 - val_ssim_loss: 0.4865 - val_mse_loss: 0.0847
# Epoch 7/100
# 888/888 - 5s - loss: 0.2876 - ssim_loss: 0.4867 - mse_loss: 0.0883 - val_loss: 0.2848 - val_ssim_loss: 0.4862 - val_mse_loss: 0.0835
# Epoch 8/100
# 888/888 - 5s - loss: 0.2879 - ssim_loss: 0.4867 - mse_loss: 0.0891 - val_loss: 0.2883 - val_ssim_loss: 0.4880 - val_mse_loss: 0.0885
# Epoch 9/100
# 888/888 - 5s - loss: 0.2888 - ssim_loss: 0.4868 - mse_loss: 0.0907 - val_loss: 0.2870 - val_ssim_loss: 0.4875 - val_mse_loss: 0.0865
# Epoch 10/100
# 888/888 - 5s - loss: 0.2896 - ssim_loss: 0.4869 - mse_loss: 0.0923 - val_loss: 0.2873 - val_ssim_loss: 0.4868 - val_mse_loss: 0.0878
# Epoch 11/100
# 888/888 - 5s - loss: 0.2898 - ssim_loss: 0.4869 - mse_loss: 0.0927 - val_loss: 0.2882 - val_ssim_loss: 0.4866 - val_mse_loss: 0.0897
# Epoch 12/100
# 888/888 - 5s - loss: 0.2901 - ssim_loss: 0.4868 - mse_loss: 0.0934 - val_loss: 0.2891 - val_ssim_loss: 0.4877 - val_mse_loss: 0.0905
# Epoch 13/100
# 888/888 - 5s - loss: 0.2901 - ssim_loss: 0.4868 - mse_loss: 0.0933 - val_loss: 0.2885 - val_ssim_loss: 0.4873 - val_mse_loss: 0.0897
# Epoch 14/100
# 888/888 - 5s - loss: 0.2904 - ssim_loss: 0.4868 - mse_loss: 0.0937 - val_loss: 0.2871 - val_ssim_loss: 0.4862 - val_mse_loss: 0.0879
# Epoch 15/100
# 888/888 - 5s - loss: 0.2904 - ssim_loss: 0.4868 - mse_loss: 0.0939 - val_loss: 0.2878 - val_ssim_loss: 0.4864 - val_mse_loss: 0.0891
# Epoch 16/100
# 888/888 - 5s - loss: 0.2905 - ssim_loss: 0.4867 - mse_loss: 0.0944 - val_loss: 0.2901 - val_ssim_loss: 0.4876 - val_mse_loss: 0.0925
# Epoch 17/100
# 888/888 - 5s - loss: 0.2906 - ssim_loss: 0.4866 - mse_loss: 0.0948 - val_loss: 0.2922 - val_ssim_loss: 0.4887 - val_mse_loss: 0.0957
# Epoch 18/100
# 888/888 - 5s - loss: 0.2911 - ssim_loss: 0.4868 - mse_loss: 0.0953 - val_loss: 0.2879 - val_ssim_loss: 0.4866 - val_mse_loss: 0.0892
# Epoch 19/100
# 888/888 - 5s - loss: 0.2908 - ssim_loss: 0.4867 - mse_loss: 0.0949 - val_loss: 0.2890 - val_ssim_loss: 0.4873 - val_mse_loss: 0.0905
# Epoch 20/100
# 888/888 - 5s - loss: 0.2908 - ssim_loss: 0.4867 - mse_loss: 0.0950 - val_loss: 0.2895 - val_ssim_loss: 0.4873 - val_mse_loss: 0.0917
# Epoch 21/100
# 888/888 - 5s - loss: 0.2909 - ssim_loss: 0.4866 - mse_loss: 0.0953 - val_loss: 0.2905 - val_ssim_loss: 0.4879 - val_mse_loss: 0.0929
# Epoch 22/100
# 888/888 - 5s - loss: 0.2913 - ssim_loss: 0.4866 - mse_loss: 0.0959 - val_loss: 0.2891 - val_ssim_loss: 0.4871 - val_mse_loss: 0.0910
# Epoch 23/100
# 888/888 - 5s - loss: 0.2910 - ssim_loss: 0.4865 - mse_loss: 0.0956 - val_loss: 0.2900 - val_ssim_loss: 0.4874 - val_mse_loss: 0.0925
# Epoch 24/100
# 888/888 - 5s - loss: 0.2910 - ssim_loss: 0.4865 - mse_loss: 0.0954 - val_loss: 0.2899 - val_ssim_loss: 0.4865 - val_mse_loss: 0.0932
# Epoch 25/100
# 888/888 - 5s - loss: 0.2911 - ssim_loss: 0.4865 - mse_loss: 0.0957 - val_loss: 0.2906 - val_ssim_loss: 0.4870 - val_mse_loss: 0.0942
# Epoch 26/100
# 888/888 - 5s - loss: 0.2913 - ssim_loss: 0.4864 - mse_loss: 0.0961 - val_loss: 0.2896 - val_ssim_loss: 0.4871 - val_mse_loss: 0.0920
# Epoch 27/100
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 888/888 - 5s - loss: 0.2910 - ssim_loss: 0.4864 - mse_loss: 0.0957 - val_loss: 0.2900 - val_ssim_loss: 0.4872 - val_mse_loss: 0.0928
# Epoch 28/100
# 888/888 - 5s - loss: 0.2866 - ssim_loss: 0.4820 - mse_loss: 0.0911 - val_loss: 0.2853 - val_ssim_loss: 0.4827 - val_mse_loss: 0.0879
# Epoch 29/100
# 888/888 - 5s - loss: 0.2863 - ssim_loss: 0.4817 - mse_loss: 0.0909 - val_loss: 0.2853 - val_ssim_loss: 0.4828 - val_mse_loss: 0.0876
# Epoch 30/100
# 888/888 - 5s - loss: 0.2862 - ssim_loss: 0.4817 - mse_loss: 0.0908 - val_loss: 0.2851 - val_ssim_loss: 0.4825 - val_mse_loss: 0.0876
# Epoch 31/100
# 888/888 - 5s - loss: 0.2862 - ssim_loss: 0.4816 - mse_loss: 0.0910 - val_loss: 0.2852 - val_ssim_loss: 0.4831 - val_mse_loss: 0.0872
# Epoch 32/100
# 888/888 - 5s - loss: 0.2862 - ssim_loss: 0.4816 - mse_loss: 0.0909 - val_loss: 0.2853 - val_ssim_loss: 0.4832 - val_mse_loss: 0.0873
# Epoch 33/100
# 888/888 - 5s - loss: 0.2861 - ssim_loss: 0.4816 - mse_loss: 0.0906 - val_loss: 0.2851 - val_ssim_loss: 0.4822 - val_mse_loss: 0.0880
# Epoch 34/100
# 888/888 - 5s - loss: 0.2861 - ssim_loss: 0.4815 - mse_loss: 0.0910 - val_loss: 0.2856 - val_ssim_loss: 0.4838 - val_mse_loss: 0.0874
# Epoch 35/100
# 888/888 - 5s - loss: 0.2861 - ssim_loss: 0.4815 - mse_loss: 0.0907 - val_loss: 0.2854 - val_ssim_loss: 0.4830 - val_mse_loss: 0.0877
# Epoch 36/100
# 888/888 - 5s - loss: 0.2862 - ssim_loss: 0.4817 - mse_loss: 0.0908 - val_loss: 0.2852 - val_ssim_loss: 0.4828 - val_mse_loss: 0.0876
# Epoch 37/100
# 888/888 - 5s - loss: 0.2861 - ssim_loss: 0.4815 - mse_loss: 0.0907 - val_loss: 0.2852 - val_ssim_loss: 0.4828 - val_mse_loss: 0.0876
# Epoch 38/100
# 888/888 - 5s - loss: 0.2861 - ssim_loss: 0.4815 - mse_loss: 0.0908 - val_loss: 0.2853 - val_ssim_loss: 0.4832 - val_mse_loss: 0.0874
# Epoch 39/100
# 888/888 - 5s - loss: 0.2860 - ssim_loss: 0.4814 - mse_loss: 0.0907 - val_loss: 0.2854 - val_ssim_loss: 0.4829 - val_mse_loss: 0.0877
# Epoch 40/100
# 888/888 - 5s - loss: 0.2860 - ssim_loss: 0.4815 - mse_loss: 0.0905 - val_loss: 0.2847 - val_ssim_loss: 0.4820 - val_mse_loss: 0.0874
# Epoch 41/100
# 888/888 - 5s - loss: 0.2860 - ssim_loss: 0.4814 - mse_loss: 0.0904 - val_loss: 0.2850 - val_ssim_loss: 0.4825 - val_mse_loss: 0.0875
# Epoch 42/100
# 888/888 - 5s - loss: 0.2860 - ssim_loss: 0.4814 - mse_loss: 0.0906 - val_loss: 0.2850 - val_ssim_loss: 0.4820 - val_mse_loss: 0.0879
# Epoch 43/100
# 888/888 - 5s - loss: 0.2860 - ssim_loss: 0.4814 - mse_loss: 0.0905 - val_loss: 0.2852 - val_ssim_loss: 0.4824 - val_mse_loss: 0.0880
# Epoch 44/100
# 888/888 - 5s - loss: 0.2860 - ssim_loss: 0.4813 - mse_loss: 0.0906 - val_loss: 0.2852 - val_ssim_loss: 0.4830 - val_mse_loss: 0.0873
# Epoch 45/100
# 888/888 - 5s - loss: 0.2859 - ssim_loss: 0.4813 - mse_loss: 0.0905 - val_loss: 0.2850 - val_ssim_loss: 0.4825 - val_mse_loss: 0.0874
# Epoch 46/100
# 888/888 - 5s - loss: 0.2859 - ssim_loss: 0.4812 - mse_loss: 0.0906 - val_loss: 0.2851 - val_ssim_loss: 0.4827 - val_mse_loss: 0.0875
# Epoch 47/100
# 888/888 - 5s - loss: 0.2859 - ssim_loss: 0.4813 - mse_loss: 0.0904 - val_loss: 0.2849 - val_ssim_loss: 0.4820 - val_mse_loss: 0.0878
# Epoch 48/100
# 888/888 - 5s - loss: 0.2860 - ssim_loss: 0.4813 - mse_loss: 0.0907 - val_loss: 0.2855 - val_ssim_loss: 0.4830 - val_mse_loss: 0.0878
# Epoch 49/100
# 888/888 - 5s - loss: 0.2860 - ssim_loss: 0.4814 - mse_loss: 0.0906 - val_loss: 0.2852 - val_ssim_loss: 0.4827 - val_mse_loss: 0.0877
# Epoch 50/100
# 888/888 - 5s - loss: 0.2859 - ssim_loss: 0.4812 - mse_loss: 0.0904 - val_loss: 0.2846 - val_ssim_loss: 0.4815 - val_mse_loss: 0.0877
# Epoch 51/100
# 888/888 - 5s - loss: 0.2858 - ssim_loss: 0.4811 - mse_loss: 0.0906 - val_loss: 0.2850 - val_ssim_loss: 0.4826 - val_mse_loss: 0.0873
# Epoch 52/100
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Restoring model weights from the end of the best epoch.
# 888/888 - 5s - loss: 0.2858 - ssim_loss: 0.4811 - mse_loss: 0.0904 - val_loss: 0.2847 - val_ssim_loss: 0.4819 - val_mse_loss: 0.0875
# Epoch 00052: early stopping

# %%
y_pred_forward = forward_model.predict(MX_test)
show_video(y_pred_forward,MX_test,200)

# %%
forward_history

# %%
forward_model.save_weights("../../data/model_stuff/forward_jelly_weights_4_23.h5")
binary_weights = forward_model.layers[0].get_weights()
inverse_weights = forward_model.layers[5].get_weights()
get_mask(forward_model)

# %%
""" 
UNET MODEL
Fixing the weights for the bin_conv1 layer as well as the dense1 layer, ie NON TRAINABLE
Feeding in weights from the forward_model above to see if that improves the results from previous session

"""
inputs = Input(shape=(30,32,32,1))
bin_conv1 = TimeDistributed(BinaryConv2D(1, kernel_size=(32,32), input_shape=(30,32,32,1),
                       data_format='channels_last',
                       H=H, kernel_lr_multiplier=kernel_lr_multiplier,
                       padding='same', use_bias=use_bias, name='bin_conv_1',trainable=False))(inputs)
resh1 = Reshape((30,32,32))(bin_conv1)
s = Lambda(streak, output_shape = streak_output_shape)(resh1)
i = Lambda(integrate_ims, output_shape = integrate_ims_output_shape) (s)
f = Flatten()(i)
dense1 = Dense(30720, activation = 'relu',trainable=False)(f)
resh2 = Reshape((30,32,32,1))(dense1)
c1 = TimeDistributed(Conv2D(1, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (resh2)
c1 = Dropout(0.1) (c1)
c1 = TimeDistributed(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c1)
p1 = TimeDistributed(MaxPooling2D((2, 2)))(c1)

c2 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same'))(p1)
c2 = Dropout(0.1) (c2)
c2 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c2)
p2 = TimeDistributed(MaxPooling2D((2, 2)) )(c2)

c3 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(p2)
c3 = Dropout(0.2) (c3)
c3 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c3)
p3 = TimeDistributed(MaxPooling2D((2, 2)) )(c3)
    
c4 = TimeDistributed(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(p3)
c4 = Dropout(0.2) (c4)
c4 = TimeDistributed(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(c4)
p4 = TimeDistributed(MaxPooling2D(pool_size=(2, 2))) (c4)

c5 = TimeDistributed(Conv2D(256, (2, 2), activation='relu', kernel_initializer='he_normal', padding='same')) (p4)
c5 = Dropout(0.3) (c5)
c5 = TimeDistributed(Conv2D(256, (2, 2), activation='relu', kernel_initializer='he_normal', padding='same')) (c5)

u6 = TimeDistributed(Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same'))(c5)
u6 = concatenate([u6, c4])
c6 = TimeDistributed( Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') )(u6)
c6 = Dropout(0.2) (c6)
c6 = TimeDistributed(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c6)

u7 = TimeDistributed(Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same') )(c6)
u7 = concatenate([u7, c3])
c7 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (u7)
c7 = Dropout(0.2) (c7)
c7 = TimeDistributed(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c7)
    
u8 = TimeDistributed(Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same') )(c7)
u8 = concatenate([u8, c2])
c8 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (u8)
c8 = Dropout(0.1) (c8)
c8 = TimeDistributed(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c8)

u9 = TimeDistributed(Conv2DTranspose(16, (3, 3), strides=(2, 2), padding='same')) (c8)
c9 = TimeDistributed(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (u9)
c9 = Dropout(0.1) (c9)
c9 = TimeDistributed(Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')) (c9)
    
outputs = TimeDistributed(Conv2D(1, (1, 1), activation='sigmoid')) (c9)

CUPNET = Model(inputs = [inputs], outputs = [outputs])
    
CUPNET.compile(optimizer = Nadam(), loss = custom_loss, metrics = ['mean_squared_error'],callbacks=[reduce_lr, early_stopping])
CUPNET.summary()
# Out:
# (None, 30, 62, 32)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30, 32, 32,  0
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 30, 32, 32, 1 1024        input_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 30, 32, 32)   0           time_distributed[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 30, 62, 32)   0           reshape[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 62, 32)       0           lambda[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1984)         0           lambda_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 30720)        60979200    flatten[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 30, 32, 32, 1 0           dense[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 30, 32, 32, 1 10          reshape_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 30, 32, 32, 1 0           time_distributed_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 30, 32, 32, 1 160         dropout[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 30, 16, 16, 1 0           time_distributed_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 30, 16, 16, 3 4640        time_distributed_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 30, 16, 16, 3 0           time_distributed_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 30, 16, 16, 3 9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 30, 8, 8, 32) 0           time_distributed_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 30, 8, 8, 64) 18496       time_distributed_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 30, 8, 8, 64) 0           time_distributed_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 30, 8, 8, 64) 36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 30, 4, 4, 64) 0           time_distributed_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 30, 4, 4, 128 73856       time_distributed_9[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 30, 4, 4, 128 0           time_distributed_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 30, 4, 4, 128 147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 30, 2, 2, 128 0           time_distributed_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 30, 2, 2, 256 131328      time_distributed_12[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 30, 2, 2, 256 0           time_distributed_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 30, 2, 2, 256 262400      dropout_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 30, 4, 4, 128 295040      time_distributed_14[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 30, 4, 4, 256 0           time_distributed_15[0][0]
#                                                                  time_distributed_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 30, 4, 4, 128 295040      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 30, 4, 4, 128 0           time_distributed_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 30, 4, 4, 128 147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 30, 8, 8, 64) 73792       time_distributed_17[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 8, 8, 128 0           time_distributed_18[0][0]
#                                                                  time_distributed_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 30, 8, 8, 64) 73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 30, 8, 8, 64) 0           time_distributed_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 30, 8, 8, 64) 36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 30, 16, 16, 3 18464       time_distributed_20[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 30, 16, 16, 6 0           time_distributed_21[0][0]
#                                                                  time_distributed_5[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 30, 16, 16, 3 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 30, 16, 16, 3 0           time_distributed_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 30, 16, 16, 3 9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 30, 32, 32, 1 4624        time_distributed_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 30, 32, 32, 1 2320        time_distributed_24[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 30, 32, 32, 1 0           time_distributed_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 30, 32, 32, 1 2320        dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 30, 32, 32, 1 17          time_distributed_26[0][0]
# ==================================================================================================
# Total params: 62,642,507
# Trainable params: 1,662,283
# Non-trainable params: 60,980,224
# __________________________________________________________________________________________________

# %%
CUPNET.load_weights("../../data/model_stuff/cupnet_jelly_weights_4_23.h5")

# %%
b = CUPNET.layers[1].get_weights()
b = binarize(tf.convert_to_tensor(b))
b = np.reshape(b,(32,32))
np.save('cupnet_jelly_mask',b)

# %%
CUPNET.layers[1].set_weights(binary_weights)
CUPNET.layers[6].set_weights(inverse_weights)
CUPNET.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 30, 32, 32,  0
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 30, 32, 32, 1 1024        input_3[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 30, 32, 32)   0           time_distributed_29[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 30, 62, 32)   0           reshape_4[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 62, 32)       0           lambda_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1984)         0           lambda_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 30720)        60979200    flatten_2[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 30, 32, 32, 1 0           dense_2[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 30, 32, 32, 1 10          reshape_5[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 30, 32, 32, 1 0           time_distributed_30[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 30, 32, 32, 1 160         dropout_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 30, 16, 16, 1 0           time_distributed_31[0][0]
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 30, 16, 16, 3 4640        time_distributed_32[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 30, 16, 16, 3 0           time_distributed_33[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 30, 16, 16, 3 9248        dropout_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 30, 8, 8, 32) 0           time_distributed_34[0][0]
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (None, 30, 8, 8, 64) 18496       time_distributed_35[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 30, 8, 8, 64) 0           time_distributed_36[0][0]
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (None, 30, 8, 8, 64) 36928       dropout_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (None, 30, 4, 4, 64) 0           time_distributed_37[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (None, 30, 4, 4, 128 73856       time_distributed_38[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 30, 4, 4, 128 0           time_distributed_39[0][0]
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (None, 30, 4, 4, 128 147584      dropout_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (None, 30, 2, 2, 128 0           time_distributed_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (None, 30, 2, 2, 256 131328      time_distributed_41[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 30, 2, 2, 256 0           time_distributed_42[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (None, 30, 2, 2, 256 262400      dropout_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (None, 30, 4, 4, 128 295040      time_distributed_43[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 30, 4, 4, 256 0           time_distributed_44[0][0]
#                                                                  time_distributed_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (None, 30, 4, 4, 128 295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 30, 4, 4, 128 0           time_distributed_45[0][0]
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (None, 30, 4, 4, 128 147584      dropout_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (None, 30, 8, 8, 64) 73792       time_distributed_46[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 30, 8, 8, 128 0           time_distributed_47[0][0]
#                                                                  time_distributed_37[0][0]
# __________________________________________________________________________________________________
# time_distributed_48 (TimeDistri (None, 30, 8, 8, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 30, 8, 8, 64) 0           time_distributed_48[0][0]
# __________________________________________________________________________________________________
# time_distributed_49 (TimeDistri (None, 30, 8, 8, 64) 36928       dropout_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_50 (TimeDistri (None, 30, 16, 16, 3 18464       time_distributed_49[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 30, 16, 16, 6 0           time_distributed_50[0][0]
#                                                                  time_distributed_34[0][0]
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (None, 30, 16, 16, 3 18464       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 30, 16, 16, 3 0           time_distributed_51[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (None, 30, 16, 16, 3 9248        dropout_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (None, 30, 32, 32, 1 4624        time_distributed_52[0][0]
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (None, 30, 32, 32, 1 2320        time_distributed_53[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 30, 32, 32, 1 0           time_distributed_54[0][0]
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (None, 30, 32, 32, 1 2320        dropout_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (None, 30, 32, 32, 1 17          time_distributed_55[0][0]
# ==================================================================================================
# Total params: 62,642,507
# Trainable params: 1,662,283
# Non-trainable params: 60,980,224
# __________________________________________________________________________________________________

# %%
""" CUPNET TRAINING """
CUPNET_history = CUPNET.fit(MX_train, My_train,
          batch_size = 32,epochs= 300,
          verbose=2,validation_data=(MX_test,My_test),callbacks=[reduce_lr,early_stopping])
# Out:
# Train on 888 samples, validate on 381 samples
# Epoch 1/300
# 888/888 - 22s - loss: 0.1172 - mean_squared_error: 0.0394 - val_loss: 0.1034 - val_mean_squared_error: 0.0371
# Epoch 2/300
# 888/888 - 13s - loss: 0.0956 - mean_squared_error: 0.0292 - val_loss: 0.0834 - val_mean_squared_error: 0.0196
# Epoch 3/300
# 888/888 - 13s - loss: 0.0821 - mean_squared_error: 0.0157 - val_loss: 0.0746 - val_mean_squared_error: 0.0136
# Epoch 4/300
# 888/888 - 13s - loss: 0.0776 - mean_squared_error: 0.0137 - val_loss: 0.0733 - val_mean_squared_error: 0.0125
# Epoch 5/300
# 888/888 - 13s - loss: 0.0745 - mean_squared_error: 0.0129 - val_loss: 0.0688 - val_mean_squared_error: 0.0111
# Epoch 6/300
# 888/888 - 13s - loss: 0.0721 - mean_squared_error: 0.0120 - val_loss: 0.0679 - val_mean_squared_error: 0.0105
# Epoch 7/300
# 888/888 - 13s - loss: 0.0702 - mean_squared_error: 0.0109 - val_loss: 0.0664 - val_mean_squared_error: 0.0096
# Epoch 8/300
# 888/888 - 13s - loss: 0.0684 - mean_squared_error: 0.0096 - val_loss: 0.0663 - val_mean_squared_error: 0.0098
# Epoch 9/300
# 888/888 - 13s - loss: 0.0675 - mean_squared_error: 0.0091 - val_loss: 0.0646 - val_mean_squared_error: 0.0081
# Epoch 10/300
# 888/888 - 13s - loss: 0.0666 - mean_squared_error: 0.0086 - val_loss: 0.0653 - val_mean_squared_error: 0.0087
# Epoch 11/300
# 888/888 - 13s - loss: 0.0663 - mean_squared_error: 0.0084 - val_loss: 0.0640 - val_mean_squared_error: 0.0077
# Epoch 12/300
# 888/888 - 13s - loss: 0.0665 - mean_squared_error: 0.0086 - val_loss: 0.0640 - val_mean_squared_error: 0.0076
# Epoch 13/300
# 888/888 - 13s - loss: 0.0654 - mean_squared_error: 0.0080 - val_loss: 0.0639 - val_mean_squared_error: 0.0075
# Epoch 14/300
# 888/888 - 13s - loss: 0.0649 - mean_squared_error: 0.0078 - val_loss: 0.0636 - val_mean_squared_error: 0.0075
# Epoch 15/300
# 888/888 - 13s - loss: 0.0647 - mean_squared_error: 0.0076 - val_loss: 0.0638 - val_mean_squared_error: 0.0073
# Epoch 16/300
# 888/888 - 13s - loss: 0.0641 - mean_squared_error: 0.0075 - val_loss: 0.0629 - val_mean_squared_error: 0.0070
# Epoch 17/300
# 888/888 - 13s - loss: 0.0639 - mean_squared_error: 0.0074 - val_loss: 0.0631 - val_mean_squared_error: 0.0070
# Epoch 18/300
# 888/888 - 13s - loss: 0.0636 - mean_squared_error: 0.0073 - val_loss: 0.0623 - val_mean_squared_error: 0.0068
# Epoch 19/300
# 888/888 - 13s - loss: 0.0634 - mean_squared_error: 0.0071 - val_loss: 0.0632 - val_mean_squared_error: 0.0069
# Epoch 20/300
# 888/888 - 13s - loss: 0.0624 - mean_squared_error: 0.0063 - val_loss: 0.0603 - val_mean_squared_error: 0.0052
# Epoch 21/300
# 888/888 - 13s - loss: 0.0612 - mean_squared_error: 0.0054 - val_loss: 0.0632 - val_mean_squared_error: 0.0066
# Epoch 22/300
# 888/888 - 13s - loss: 0.0619 - mean_squared_error: 0.0058 - val_loss: 0.0602 - val_mean_squared_error: 0.0048
# Epoch 23/300
# 888/888 - 13s - loss: 0.0600 - mean_squared_error: 0.0049 - val_loss: 0.0593 - val_mean_squared_error: 0.0045
# Epoch 24/300
# 888/888 - 13s - loss: 0.0598 - mean_squared_error: 0.0048 - val_loss: 0.0599 - val_mean_squared_error: 0.0049
# Epoch 25/300
# 888/888 - 13s - loss: 0.0594 - mean_squared_error: 0.0048 - val_loss: 0.0635 - val_mean_squared_error: 0.0077
# Epoch 26/300
# 888/888 - 13s - loss: 0.0593 - mean_squared_error: 0.0048 - val_loss: 0.0591 - val_mean_squared_error: 0.0047
# Epoch 27/300
# 888/888 - 13s - loss: 0.0588 - mean_squared_error: 0.0046 - val_loss: 0.0590 - val_mean_squared_error: 0.0044
# Epoch 28/300
# 888/888 - 13s - loss: 0.0585 - mean_squared_error: 0.0045 - val_loss: 0.0580 - val_mean_squared_error: 0.0043
# Epoch 29/300
# 888/888 - 13s - loss: 0.0582 - mean_squared_error: 0.0044 - val_loss: 0.0579 - val_mean_squared_error: 0.0042
# Epoch 30/300
# 888/888 - 13s - loss: 0.0613 - mean_squared_error: 0.0065 - val_loss: 0.0674 - val_mean_squared_error: 0.0087
# Epoch 31/300
# 888/888 - 13s - loss: 0.0642 - mean_squared_error: 0.0071 - val_loss: 0.0601 - val_mean_squared_error: 0.0047
# Epoch 32/300
# 888/888 - 13s - loss: 0.0590 - mean_squared_error: 0.0045 - val_loss: 0.0590 - val_mean_squared_error: 0.0044
# Epoch 33/300
# 888/888 - 13s - loss: 0.0582 - mean_squared_error: 0.0044 - val_loss: 0.0577 - val_mean_squared_error: 0.0041
# Epoch 34/300
# 888/888 - 13s - loss: 0.0580 - mean_squared_error: 0.0044 - val_loss: 0.0586 - val_mean_squared_error: 0.0043
# Epoch 35/300
# 888/888 - 13s - loss: 0.0577 - mean_squared_error: 0.0044 - val_loss: 0.0582 - val_mean_squared_error: 0.0042
# Epoch 36/300
# 888/888 - 13s - loss: 0.0572 - mean_squared_error: 0.0042 - val_loss: 0.0573 - val_mean_squared_error: 0.0041
# Epoch 37/300
# 888/888 - 13s - loss: 0.0571 - mean_squared_error: 0.0042 - val_loss: 0.0577 - val_mean_squared_error: 0.0043
# Epoch 38/300
# 888/888 - 13s - loss: 0.0572 - mean_squared_error: 0.0043 - val_loss: 0.0574 - val_mean_squared_error: 0.0041
# Epoch 39/300
# 888/888 - 13s - loss: 0.0569 - mean_squared_error: 0.0042 - val_loss: 0.0568 - val_mean_squared_error: 0.0040
# Epoch 40/300
# 888/888 - 13s - loss: 0.0568 - mean_squared_error: 0.0043 - val_loss: 0.0564 - val_mean_squared_error: 0.0040
# Epoch 41/300
# 888/888 - 13s - loss: 0.0567 - mean_squared_error: 0.0042 - val_loss: 0.0568 - val_mean_squared_error: 0.0041
# Epoch 42/300
# 888/888 - 13s - loss: 0.0567 - mean_squared_error: 0.0043 - val_loss: 0.0562 - val_mean_squared_error: 0.0039
# Epoch 43/300
# 888/888 - 13s - loss: 0.0562 - mean_squared_error: 0.0041 - val_loss: 0.0560 - val_mean_squared_error: 0.0039
# Epoch 44/300
# 888/888 - 13s - loss: 0.0562 - mean_squared_error: 0.0041 - val_loss: 0.0561 - val_mean_squared_error: 0.0039
# Epoch 45/300
# 888/888 - 13s - loss: 0.0560 - mean_squared_error: 0.0041 - val_loss: 0.0559 - val_mean_squared_error: 0.0040
# Epoch 46/300
# 888/888 - 13s - loss: 0.0560 - mean_squared_error: 0.0042 - val_loss: 0.0568 - val_mean_squared_error: 0.0040
# Epoch 47/300
# 888/888 - 13s - loss: 0.0561 - mean_squared_error: 0.0042 - val_loss: 0.0561 - val_mean_squared_error: 0.0039
# Epoch 48/300
# 888/888 - 13s - loss: 0.0556 - mean_squared_error: 0.0041 - val_loss: 0.0560 - val_mean_squared_error: 0.0041
# Epoch 49/300
# 888/888 - 13s - loss: 0.0553 - mean_squared_error: 0.0040 - val_loss: 0.0554 - val_mean_squared_error: 0.0038
# Epoch 50/300
# 888/888 - 13s - loss: 0.0555 - mean_squared_error: 0.0040 - val_loss: 0.0551 - val_mean_squared_error: 0.0038
# Epoch 51/300
# 888/888 - 13s - loss: 0.0551 - mean_squared_error: 0.0040 - val_loss: 0.0554 - val_mean_squared_error: 0.0038
# Epoch 52/300
# 888/888 - 13s - loss: 0.0549 - mean_squared_error: 0.0040 - val_loss: 0.0558 - val_mean_squared_error: 0.0039
# Epoch 53/300
# 888/888 - 13s - loss: 0.0553 - mean_squared_error: 0.0041 - val_loss: 0.0555 - val_mean_squared_error: 0.0039
# Epoch 54/300
# 888/888 - 13s - loss: 0.0546 - mean_squared_error: 0.0039 - val_loss: 0.0543 - val_mean_squared_error: 0.0038
# Epoch 55/300
# 888/888 - 13s - loss: 0.0544 - mean_squared_error: 0.0038 - val_loss: 0.0549 - val_mean_squared_error: 0.0038
# Epoch 56/300
# 888/888 - 13s - loss: 0.0549 - mean_squared_error: 0.0040 - val_loss: 0.0548 - val_mean_squared_error: 0.0038
# Epoch 57/300
# 888/888 - 13s - loss: 0.0542 - mean_squared_error: 0.0038 - val_loss: 0.0539 - val_mean_squared_error: 0.0037
# Epoch 58/300
# 888/888 - 13s - loss: 0.0545 - mean_squared_error: 0.0039 - val_loss: 0.0540 - val_mean_squared_error: 0.0036
# Epoch 59/300
# 888/888 - 13s - loss: 0.0543 - mean_squared_error: 0.0039 - val_loss: 0.0544 - val_mean_squared_error: 0.0037
# Epoch 60/300
# 888/888 - 13s - loss: 0.0539 - mean_squared_error: 0.0038 - val_loss: 0.0531 - val_mean_squared_error: 0.0036
# Epoch 61/300
# 888/888 - 13s - loss: 0.0537 - mean_squared_error: 0.0038 - val_loss: 0.0555 - val_mean_squared_error: 0.0039
# Epoch 62/300
# 888/888 - 13s - loss: 0.0541 - mean_squared_error: 0.0039 - val_loss: 0.0542 - val_mean_squared_error: 0.0037
# Epoch 63/300
# 888/888 - 13s - loss: 0.0537 - mean_squared_error: 0.0039 - val_loss: 0.0539 - val_mean_squared_error: 0.0037
# Epoch 64/300
# 888/888 - 13s - loss: 0.0536 - mean_squared_error: 0.0038 - val_loss: 0.0535 - val_mean_squared_error: 0.0037
# Epoch 65/300
# 888/888 - 13s - loss: 0.0533 - mean_squared_error: 0.0038 - val_loss: 0.0533 - val_mean_squared_error: 0.0036
# Epoch 66/300
# 888/888 - 13s - loss: 0.0533 - mean_squared_error: 0.0037 - val_loss: 0.0535 - val_mean_squared_error: 0.0036
# Epoch 67/300
# 888/888 - 13s - loss: 0.0532 - mean_squared_error: 0.0038 - val_loss: 0.0528 - val_mean_squared_error: 0.0037
# Epoch 68/300
# 888/888 - 13s - loss: 0.0529 - mean_squared_error: 0.0037 - val_loss: 0.0534 - val_mean_squared_error: 0.0036
# Epoch 69/300
# 888/888 - 13s - loss: 0.0530 - mean_squared_error: 0.0037 - val_loss: 0.0543 - val_mean_squared_error: 0.0037
# Epoch 70/300
# 888/888 - 13s - loss: 0.0529 - mean_squared_error: 0.0037 - val_loss: 0.0529 - val_mean_squared_error: 0.0036
# Epoch 71/300
# 888/888 - 13s - loss: 0.0525 - mean_squared_error: 0.0036 - val_loss: 0.0528 - val_mean_squared_error: 0.0036
# Epoch 72/300
# 888/888 - 13s - loss: 0.0525 - mean_squared_error: 0.0036 - val_loss: 0.0527 - val_mean_squared_error: 0.0035
# Epoch 73/300
# 888/888 - 13s - loss: 0.0525 - mean_squared_error: 0.0036 - val_loss: 0.0540 - val_mean_squared_error: 0.0038
# Epoch 74/300
# 888/888 - 13s - loss: 0.0521 - mean_squared_error: 0.0036 - val_loss: 0.0535 - val_mean_squared_error: 0.0035
# Epoch 75/300
# 888/888 - 13s - loss: 0.0520 - mean_squared_error: 0.0036 - val_loss: 0.0527 - val_mean_squared_error: 0.0035
# Epoch 76/300
# 888/888 - 13s - loss: 0.0524 - mean_squared_error: 0.0036 - val_loss: 0.0522 - val_mean_squared_error: 0.0036
# Epoch 77/300
# 888/888 - 13s - loss: 0.0518 - mean_squared_error: 0.0036 - val_loss: 0.0522 - val_mean_squared_error: 0.0034
# Epoch 78/300
# 888/888 - 13s - loss: 0.0518 - mean_squared_error: 0.0036 - val_loss: 0.0523 - val_mean_squared_error: 0.0035
# Epoch 79/300
# 888/888 - 13s - loss: 0.0517 - mean_squared_error: 0.0035 - val_loss: 0.0522 - val_mean_squared_error: 0.0034
# Epoch 80/300
# 888/888 - 13s - loss: 0.0514 - mean_squared_error: 0.0035 - val_loss: 0.0513 - val_mean_squared_error: 0.0034
# Epoch 81/300
# 888/888 - 13s - loss: 0.0517 - mean_squared_error: 0.0035 - val_loss: 0.0517 - val_mean_squared_error: 0.0035
# Epoch 82/300
# 888/888 - 13s - loss: 0.0516 - mean_squared_error: 0.0036 - val_loss: 0.0522 - val_mean_squared_error: 0.0037
# Epoch 83/300
# 888/888 - 13s - loss: 0.0513 - mean_squared_error: 0.0035 - val_loss: 0.0518 - val_mean_squared_error: 0.0035
# Epoch 84/300
# 888/888 - 13s - loss: 0.0511 - mean_squared_error: 0.0035 - val_loss: 0.0517 - val_mean_squared_error: 0.0034
# Epoch 85/300
# 888/888 - 13s - loss: 0.0509 - mean_squared_error: 0.0035 - val_loss: 0.0520 - val_mean_squared_error: 0.0035
# Epoch 86/300
# 888/888 - 13s - loss: 0.0513 - mean_squared_error: 0.0036 - val_loss: 0.0525 - val_mean_squared_error: 0.0035
# Epoch 87/300
# 888/888 - 13s - loss: 0.0510 - mean_squared_error: 0.0035 - val_loss: 0.0512 - val_mean_squared_error: 0.0034
# Epoch 88/300
# 888/888 - 13s - loss: 0.0507 - mean_squared_error: 0.0034 - val_loss: 0.0523 - val_mean_squared_error: 0.0034
# Epoch 89/300
# 888/888 - 13s - loss: 0.0507 - mean_squared_error: 0.0034 - val_loss: 0.0520 - val_mean_squared_error: 0.0034
# Epoch 90/300
# 888/888 - 13s - loss: 0.0506 - mean_squared_error: 0.0035 - val_loss: 0.0515 - val_mean_squared_error: 0.0034
# Epoch 91/300
# 888/888 - 13s - loss: 0.0503 - mean_squared_error: 0.0034 - val_loss: 0.0510 - val_mean_squared_error: 0.0034
# Epoch 92/300
# 888/888 - 13s - loss: 0.0504 - mean_squared_error: 0.0034 - val_loss: 0.0511 - val_mean_squared_error: 0.0037
# Epoch 93/300
# 888/888 - 13s - loss: 0.0505 - mean_squared_error: 0.0035 - val_loss: 0.0516 - val_mean_squared_error: 0.0033
# Epoch 94/300
# 888/888 - 13s - loss: 0.0501 - mean_squared_error: 0.0034 - val_loss: 0.0517 - val_mean_squared_error: 0.0034
# Epoch 95/300
# 888/888 - 13s - loss: 0.0499 - mean_squared_error: 0.0033 - val_loss: 0.0513 - val_mean_squared_error: 0.0034
# Epoch 96/300
# 888/888 - 13s - loss: 0.0502 - mean_squared_error: 0.0034 - val_loss: 0.0508 - val_mean_squared_error: 0.0034
# Epoch 97/300
# 888/888 - 13s - loss: 0.0501 - mean_squared_error: 0.0034 - val_loss: 0.0510 - val_mean_squared_error: 0.0034
# Epoch 98/300
# 888/888 - 13s - loss: 0.0499 - mean_squared_error: 0.0034 - val_loss: 0.0514 - val_mean_squared_error: 0.0033
# Epoch 99/300
# 888/888 - 13s - loss: 0.0495 - mean_squared_error: 0.0033 - val_loss: 0.0509 - val_mean_squared_error: 0.0033
# Epoch 100/300
# 888/888 - 13s - loss: 0.0496 - mean_squared_error: 0.0033 - val_loss: 0.0527 - val_mean_squared_error: 0.0036
# Epoch 101/300
# 888/888 - 13s - loss: 0.0496 - mean_squared_error: 0.0033 - val_loss: 0.0504 - val_mean_squared_error: 0.0033
# Epoch 102/300
# 888/888 - 13s - loss: 0.0493 - mean_squared_error: 0.0033 - val_loss: 0.0519 - val_mean_squared_error: 0.0034
# Epoch 103/300
# 888/888 - 13s - loss: 0.0493 - mean_squared_error: 0.0033 - val_loss: 0.0524 - val_mean_squared_error: 0.0036
# Epoch 104/300
# 888/888 - 13s - loss: 0.0494 - mean_squared_error: 0.0033 - val_loss: 0.0507 - val_mean_squared_error: 0.0034
# Epoch 105/300
# 888/888 - 13s - loss: 0.0491 - mean_squared_error: 0.0033 - val_loss: 0.0515 - val_mean_squared_error: 0.0033
# Epoch 106/300
# 888/888 - 13s - loss: 0.0488 - mean_squared_error: 0.0032 - val_loss: 0.0511 - val_mean_squared_error: 0.0033
# Epoch 107/300
# 888/888 - 13s - loss: 0.0492 - mean_squared_error: 0.0033 - val_loss: 0.0515 - val_mean_squared_error: 0.0034
# Epoch 108/300
# 888/888 - 13s - loss: 0.0488 - mean_squared_error: 0.0032 - val_loss: 0.0502 - val_mean_squared_error: 0.0033
# Epoch 109/300
# 888/888 - 13s - loss: 0.0487 - mean_squared_error: 0.0032 - val_loss: 0.0508 - val_mean_squared_error: 0.0033
# Epoch 110/300
# 888/888 - 13s - loss: 0.0489 - mean_squared_error: 0.0032 - val_loss: 0.0515 - val_mean_squared_error: 0.0034
# Epoch 111/300
# 888/888 - 13s - loss: 0.0486 - mean_squared_error: 0.0032 - val_loss: 0.0511 - val_mean_squared_error: 0.0033
# Epoch 112/300
# 888/888 - 13s - loss: 0.0486 - mean_squared_error: 0.0032 - val_loss: 0.0514 - val_mean_squared_error: 0.0033
# Epoch 113/300
# 888/888 - 13s - loss: 0.0482 - mean_squared_error: 0.0032 - val_loss: 0.0517 - val_mean_squared_error: 0.0033
# Epoch 114/300
# 888/888 - 13s - loss: 0.0484 - mean_squared_error: 0.0032 - val_loss: 0.0506 - val_mean_squared_error: 0.0033
# Epoch 115/300
# 888/888 - 13s - loss: 0.0485 - mean_squared_error: 0.0032 - val_loss: 0.0510 - val_mean_squared_error: 0.0033
# Epoch 116/300
# 888/888 - 13s - loss: 0.0485 - mean_squared_error: 0.0032 - val_loss: 0.0513 - val_mean_squared_error: 0.0033
# Epoch 117/300
# 888/888 - 13s - loss: 0.0482 - mean_squared_error: 0.0032 - val_loss: 0.0518 - val_mean_squared_error: 0.0034
# Epoch 118/300
# 888/888 - 13s - loss: 0.0482 - mean_squared_error: 0.0032 - val_loss: 0.0508 - val_mean_squared_error: 0.0033
# Epoch 119/300
# 888/888 - 13s - loss: 0.0480 - mean_squared_error: 0.0031 - val_loss: 0.0506 - val_mean_squared_error: 0.0033
# Epoch 120/300
# 888/888 - 13s - loss: 0.0479 - mean_squared_error: 0.0032 - val_loss: 0.0502 - val_mean_squared_error: 0.0032
# Epoch 121/300
# 888/888 - 13s - loss: 0.0481 - mean_squared_error: 0.0032 - val_loss: 0.0505 - val_mean_squared_error: 0.0033
# Epoch 122/300
# 888/888 - 13s - loss: 0.0477 - mean_squared_error: 0.0031 - val_loss: 0.0512 - val_mean_squared_error: 0.0033
# Epoch 123/300
# 888/888 - 13s - loss: 0.0475 - mean_squared_error: 0.0031 - val_loss: 0.0514 - val_mean_squared_error: 0.0033
# Epoch 124/300
# 888/888 - 13s - loss: 0.0474 - mean_squared_error: 0.0031 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 125/300
# 888/888 - 13s - loss: 0.0481 - mean_squared_error: 0.0032 - val_loss: 0.0509 - val_mean_squared_error: 0.0033
# Epoch 126/300
# 888/888 - 13s - loss: 0.0475 - mean_squared_error: 0.0031 - val_loss: 0.0507 - val_mean_squared_error: 0.0032
# Epoch 127/300
# 888/888 - 13s - loss: 0.0474 - mean_squared_error: 0.0031 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 128/300
# 888/888 - 13s - loss: 0.0472 - mean_squared_error: 0.0031 - val_loss: 0.0508 - val_mean_squared_error: 0.0033
# Epoch 129/300
# 888/888 - 13s - loss: 0.0473 - mean_squared_error: 0.0031 - val_loss: 0.0502 - val_mean_squared_error: 0.0032
# Epoch 130/300
# 888/888 - 13s - loss: 0.0472 - mean_squared_error: 0.0031 - val_loss: 0.0504 - val_mean_squared_error: 0.0034
# Epoch 131/300
# 888/888 - 13s - loss: 0.0474 - mean_squared_error: 0.0031 - val_loss: 0.0506 - val_mean_squared_error: 0.0033
# Epoch 132/300
# 888/888 - 13s - loss: 0.0470 - mean_squared_error: 0.0030 - val_loss: 0.0506 - val_mean_squared_error: 0.0032
# Epoch 133/300
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 888/888 - 13s - loss: 0.0470 - mean_squared_error: 0.0030 - val_loss: 0.0507 - val_mean_squared_error: 0.0033
# Epoch 134/300
# 888/888 - 13s - loss: 0.0463 - mean_squared_error: 0.0030 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 135/300
# 888/888 - 13s - loss: 0.0461 - mean_squared_error: 0.0030 - val_loss: 0.0503 - val_mean_squared_error: 0.0032
# Epoch 136/300
# 888/888 - 13s - loss: 0.0461 - mean_squared_error: 0.0029 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 137/300
# 888/888 - 13s - loss: 0.0460 - mean_squared_error: 0.0029 - val_loss: 0.0502 - val_mean_squared_error: 0.0032
# Epoch 138/300
# 888/888 - 13s - loss: 0.0460 - mean_squared_error: 0.0029 - val_loss: 0.0501 - val_mean_squared_error: 0.0032
# Epoch 139/300
# 888/888 - 13s - loss: 0.0458 - mean_squared_error: 0.0029 - val_loss: 0.0504 - val_mean_squared_error: 0.0032
# Epoch 140/300
# 888/888 - 13s - loss: 0.0458 - mean_squared_error: 0.0029 - val_loss: 0.0506 - val_mean_squared_error: 0.0032
# Epoch 141/300
# 888/888 - 13s - loss: 0.0457 - mean_squared_error: 0.0029 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 142/300
# 888/888 - 13s - loss: 0.0457 - mean_squared_error: 0.0029 - val_loss: 0.0504 - val_mean_squared_error: 0.0032
# Epoch 143/300
# 888/888 - 13s - loss: 0.0457 - mean_squared_error: 0.0029 - val_loss: 0.0504 - val_mean_squared_error: 0.0032
# Epoch 144/300
# 888/888 - 13s - loss: 0.0456 - mean_squared_error: 0.0029 - val_loss: 0.0503 - val_mean_squared_error: 0.0032
# Epoch 145/300
# 888/888 - 13s - loss: 0.0455 - mean_squared_error: 0.0029 - val_loss: 0.0506 - val_mean_squared_error: 0.0032
# Epoch 146/300
# 888/888 - 13s - loss: 0.0456 - mean_squared_error: 0.0029 - val_loss: 0.0504 - val_mean_squared_error: 0.0032
# Epoch 147/300
# 888/888 - 13s - loss: 0.0456 - mean_squared_error: 0.0029 - val_loss: 0.0506 - val_mean_squared_error: 0.0032
# Epoch 148/300
# 888/888 - 13s - loss: 0.0453 - mean_squared_error: 0.0029 - val_loss: 0.0506 - val_mean_squared_error: 0.0032
# Epoch 149/300
# 888/888 - 13s - loss: 0.0453 - mean_squared_error: 0.0029 - val_loss: 0.0506 - val_mean_squared_error: 0.0032
# Epoch 150/300
# 888/888 - 13s - loss: 0.0453 - mean_squared_error: 0.0029 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 151/300
# 888/888 - 13s - loss: 0.0454 - mean_squared_error: 0.0029 - val_loss: 0.0510 - val_mean_squared_error: 0.0032
# Epoch 152/300
# 888/888 - 13s - loss: 0.0453 - mean_squared_error: 0.0029 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 153/300
# 888/888 - 13s - loss: 0.0452 - mean_squared_error: 0.0029 - val_loss: 0.0501 - val_mean_squared_error: 0.0032
# Epoch 154/300
# 888/888 - 13s - loss: 0.0452 - mean_squared_error: 0.0029 - val_loss: 0.0503 - val_mean_squared_error: 0.0032
# Epoch 155/300
# 888/888 - 13s - loss: 0.0451 - mean_squared_error: 0.0029 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 156/300
# 888/888 - 13s - loss: 0.0451 - mean_squared_error: 0.0029 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 157/300
# 888/888 - 13s - loss: 0.0450 - mean_squared_error: 0.0029 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 158/300
#
# Epoch 00158: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 888/888 - 13s - loss: 0.0449 - mean_squared_error: 0.0028 - val_loss: 0.0504 - val_mean_squared_error: 0.0032
# Epoch 159/300
# 888/888 - 13s - loss: 0.0447 - mean_squared_error: 0.0028 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 160/300
# 888/888 - 13s - loss: 0.0446 - mean_squared_error: 0.0028 - val_loss: 0.0504 - val_mean_squared_error: 0.0032
# Epoch 161/300
# 888/888 - 13s - loss: 0.0446 - mean_squared_error: 0.0028 - val_loss: 0.0504 - val_mean_squared_error: 0.0032
# Epoch 162/300
# 888/888 - 13s - loss: 0.0445 - mean_squared_error: 0.0028 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 163/300
# 888/888 - 13s - loss: 0.0445 - mean_squared_error: 0.0028 - val_loss: 0.0507 - val_mean_squared_error: 0.0032
# Epoch 164/300
# 888/888 - 13s - loss: 0.0445 - mean_squared_error: 0.0028 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 165/300
# 888/888 - 13s - loss: 0.0443 - mean_squared_error: 0.0028 - val_loss: 0.0505 - val_mean_squared_error: 0.0032
# Epoch 166/300
# 888/888 - 13s - loss: 0.0444 - mean_squared_error: 0.0028 - val_loss: 0.0504 - val_mean_squared_error: 0.0032
# Epoch 167/300
# 888/888 - 13s - loss: 0.0443 - mean_squared_error: 0.0028 - val_loss: 0.0509 - val_mean_squared_error: 0.0032
# Epoch 168/300
# 888/888 - 13s - loss: 0.0444 - mean_squared_error: 0.0028 - val_loss: 0.0503 - val_mean_squared_error: 0.0031
# Epoch 169/300
# 888/888 - 13s - loss: 0.0443 - mean_squared_error: 0.0028 - val_loss: 0.0504 - val_mean_squared_error: 0.0032
# Epoch 170/300
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error,lr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-8e8cfde73426> in <module>
#       2 CUPNET_history = CUPNET.fit(MX_train, My_train,
#       3           batch_size = 32,epochs= 300,
# ----> 4           verbose=2,validation_data=(MX_test,My_test),callbacks=[reduce_lr,early_stopping])
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     322                 mode=ModeKeys.TRAIN,
#     323                 training_context=training_context,
# --> 324                 total_epochs=epochs)
#     325             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     326
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     121         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     122       try:
# --> 123         batch_outs = execution_function(iterator)
#     124       except (StopIteration, errors.OutOfRangeError):
#     125         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      84     # `numpy` translates Tensors to values in Eager mode.
#      85     return nest.map_structure(_non_none_constant_value,
# ---> 86                               distributed_function(input_fn))
#      87
#      88   return execution_function
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     533
#     534   return pack_sequence_as(
# --> 535       structure[0], [func(*x) for x in entries],
#     536       expand_composites=expand_composites)
#     537
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\util\nest.py in <listcomp>(.0)
#     533
#     534   return pack_sequence_as(
# --> 535       structure[0], [func(*x) for x in entries],
#     536       expand_composites=expand_composites)
#     537
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in _non_none_constant_value(v)
#      90
#      91 def _non_none_constant_value(v):
# ---> 92   constant_value = tensor_util.constant_value(v)
#      93   return constant_value if constant_value is not None else v
#      94
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\framework\tensor_util.py in constant_value(tensor, partial)
#     790   """
#     791   if isinstance(tensor, ops.EagerTensor):
# --> 792     return tensor.numpy()
#     793   if not is_tensor(tensor):
#     794     return tensor
#
# ~\AppData\Local\Continuum\anaconda3\envs\CUPNET\lib\site-packages\tensorflow_core\python\framework\ops.py in numpy(self)
#     931       ValueError: if the type of this Tensor is not representable in numpy.
#     932     """
# --> 933     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     934     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     935
#
# KeyboardInterrupt:

# %%
CUPNET.save_weights("../../data/model_stuff/cupnet_jelly_weights_4_23.h5")

# %%
print(CUPNET_history.history.keys())
# Out:
# dict_keys(['loss', 'mean_squared_error', 'val_loss', 'val_mean_squared_error', 'lr'])

# %%
# summarize history for loss
plt.plot(CUPNET_history.history['loss'])
plt.plot(CUPNET_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(forward_history.history['loss'])
plt.plot(forward_history.history['val_loss'])
plt.title('forward_model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_train_pred = CUPNET.predict(MX_train)
y_test_pred = CUPNET.predict(MX_test)

# %%
show_video(y_test_pred,MX_test,200)

# %%
def store_many_hdf5(images,name):

    num_images = len(images)
    try:
        os.mkdir("../../data/hdf5")
    except: 
        pass

    # Create a new HDF5 file
    file = h5py.File(hdf5_dir / f"{name}_vids.h5", "w")

    # Create a dataset in the file
    dataset = file.create_dataset(
        "images", data=images
    )    
    
    file.close()

# %%
np.save("../../data/hdf5/u_net_jelly_test_ims",y_test_pred)

# %%
store_many_hdf5(y_test_pred,"u_net_predict")

# %%
import scipy.io as sio
twist_jelly = sio.loadmat('../../data/hdf5/jelly_resized.mat')
jelly = np.asarray(twist_jelly['sample'])
jelly = np.transpose(jelly,(2,0,1))
jelly = np.reshape(jelly[30:60], (1,30,32,32,1))
print(np.shape(jelly))
# Out:
# (1, 30, 32, 32, 1)

# %%
j_pred = CUPNET.predict(jelly)
